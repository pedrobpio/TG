# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.manifold import TSNE

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# df = pd.read_csv("teste.csv", index_col=0)

# %%
# df[df['ID Aluno']==208149] #id
import warnings
warnings.filterwarnings('ignore')

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.offline as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # preparing data

# %%
primeiroCiC = ['116301', '118001', '118010', '113034', '140481', '145971']
segundoCiC = ['116319', '115045', '118028', '118036', '113042']
terceiroCiC = ['118044', '118052', '113956', '113051', '117366']


primeiroLic1 =['116793', '117366', '145971', '147389', '194221']
segundoLic1 = ['113034', '116301', '125156']
terceiroLic1 = ['115045', '116319', '125172']

primeiroLic2 =['113492', '194221', '113450', '113476']
segundoLic2 = ['113034', '116319', '191027', '150649', '194280']
terceiroLic2 = ['115045', '113093', '117366', '117889']

primeiroEngComp =['113034', '113093', '113476', '117528', '118001', '118010']
segundoEngComp = ['118028', '118036', '113042', '115045', '116319']
terceiroEngComp =['113051', '117242', '170054', '201600', '206075']


primeiroMec = ['114626', '114634', '118010', '113476', '113034', '118001', '168891']
segundoMec = ['168891', '113093', '118028', '118036', '115045', '168874']
terceiroMec = ['113051', '118044', '118052', '168769', '116319']

primeiroRedes = ['113034', '113093', '118001', '118010', '167959']
segundoRedes = ['113042', '115045', '118028', '118036', '169676']
terceiroRedes = ['113051', '113301', '167983', '169749']


undropableCol = ["curso","saiu","Cotista","Raça","Sexo","Tipo de Escola"]#, 'Ingresso_unb'

# %%
df0 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_0.csv", index_col=0)
df1 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_1.csv", index_col=0)
df2 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_2.csv", index_col=0)
df3 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_3.csv", index_col=0)
df4 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_4.csv", index_col=0)
df5 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_5.csv", index_col=0)

# %%
dfComp = df0[undropableCol+primeiroLic1+segundoLic1+terceiroLic1].fillna(-1)
dfRedes = df1[undropableCol+primeiroRedes+segundoRedes+terceiroRedes].fillna(-1)
dfCic = df2[undropableCol+primeiroCiC+segundoCiC+terceiroCiC].fillna(-1) 
dfMec = df3[undropableCol+primeiroMec+segundoMec+terceiroMec].fillna(-1) 
dfEng = df4[undropableCol+primeiroEngComp+segundoEngComp+terceiroEngComp].fillna(-1)

# %% [markdown]
# # PCA

# %%
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)

# %%
def PCA (df, currentLabel = 'saiu'):
    data = (
        df

    )
    
    x = data.iloc[:].values
    y = data[currentLabel].values

    data[currentLabel]
    numColors = len(data[currentLabel].unique())

    sklearn_pca = sklearnPCA(n_components=2)

    Y_sklearn = sklearn_pca.fit_transform(x)

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    with plt.style.context('seaborn-whitegrid'):
        plt.figure(figsize=(15, 10))
        for lab, col in zip(data[currentLabel].unique(),
                            colorList):
            plt.scatter(Y_sklearn[y==lab, 0],
                        Y_sklearn[y==lab, 1],
                        label=lab,
                        c=col)
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend(loc='lower right')
        plt.tight_layout()
        plt.show()

    plt.show()

# %% [markdown]
# # TSNE

# %%
def formatColor(color):
    return 'rgb('+str(int(color[0]*255))+','+str(int(color[1]*255))+','+str(int(color[2]*255))+')'

    
def tsne(df, currentLabel = 'saiu'):
    a = df
    X = a.values
    X_embedded = TSNE(n_components=2).fit_transform(X)
    
    
    data = a
    Y_sklearn = X_embedded
    y = data[currentLabel].values
    numColors = len(data[currentLabel].unique())

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    traceArr = []
    for lab, col in zip(data[currentLabel].unique(),
                        colorList):
        
        trace1 = go.Scatter(
            x=Y_sklearn[y==lab, 0],
            y=Y_sklearn[y==lab, 1],
#             z=Y_sklearn[y==lab, 2],
            mode='markers',
            name = str(lab),
            marker=dict(
                size=5,
                color=formatColor(col),
                opacity=0.8
            )
        )
        traceArr.append(trace1)

    data = traceArr
    layout = go.Layout(
        margin=dict(
            l=0,
            r=0,
            b=0,
            t=0
        )
    )
    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, filename='3d-scatter-colorscale')

# %%
# draw2dFrame(a, X_embedded, 'saiu')

# %% [markdown]
# # knn

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# a = a[a["saiu"]!=0]
# y = a["saiu"]
# X = a.drop(["saiu"], axis = 1)

# %%
def knn (df, currentLabel = 'saiu'):
    a = df[df[currentLabel]!=0]
    y = a[currentLabel]
    X = a.drop([currentLabel], axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    scaler = StandardScaler()  
    scaler.fit(X_train)

    X_train = scaler.transform(X_train)  
    X_test = scaler.transform(X_test)  
    
    classifier = KNeighborsClassifier(n_neighbors=2)  
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    
    print(confusion_matrix(y_test, y_pred))  
    print(classification_report(y_test, y_pred))

# %%
# scaler = StandardScaler()  
# scaler.fit(X_train)

# X_train = scaler.transform(X_train)  
# X_test = scaler.transform(X_test)

# %%
# classifier = KNeighborsClassifier(n_neighbors=2)  
# classifier.fit(X_train, y_train)
# y_pred = classifier.predict(X_test)

# %%
 
# print(confusion_matrix(y_test, y_pred))  
# print(classification_report(y_test, y_pred))
# knn(X, y)

# %%
# a

# %% [markdown]
# # correlação heatmap

# %%
def corrMat(df):
    f = (df).corr('spearman')
    plt.figure(figsize=(16, 6))
    sns.heatmap(f, annot=True)

# %% [markdown]
# # gradient boosting

# %%
from sklearn import ensemble

def gradent(df, currentLabel = 'saiu'):
    params = {
        'n_estimators': 150,
        'max_depth': 6,
        'learning_rate': 0.1,
        'criterion': 'friedman_mse'
    }
    
    a = df[df[currentLabel]!=0]
    y = a[currentLabel]
    X = a.drop([currentLabel], axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    
    gradient_boosting_regressor = ensemble.GradientBoostingRegressor(**params)

    gradient_boosting_regressor.fit(X_train, y_train)
    
    y_pred = gradient_boosting_regressor.predict(X_test)
    y_pred = (y_pred>0)*1
    y_pred = np.array([x if x !=0 else -1 for x in y_pred])
#     print (y_pred)
    print(confusion_matrix(y_test, y_pred))  
    print(classification_report(y_test, y_pred))

# %%
gradent(dfComp)
# Out:
# [[ 46  12]
#  [ 24 110]]
#               precision    recall  f1-score   support
#
#           -1       0.66      0.79      0.72        58
#            1       0.90      0.82      0.86       134
#
#    micro avg       0.81      0.81      0.81       192
#    macro avg       0.78      0.81      0.79       192
# weighted avg       0.83      0.81      0.82       192

# %% [markdown]
# ## Comp

# %%
PCA(dfComp)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfComp)
# Out:
# <div id="5413ee66-156d-4d11-aaa4-e4e695f96ce2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("5413ee66-156d-4d11-aaa4-e4e695f96ce2")) {
#     Plotly.newPlot("5413ee66-156d-4d11-aaa4-e4e695f96ce2", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [12.650293350219727, 10.837420463562012, 11.480324745178223, 25.360937118530273, 12.701208114624023, 9.327995300292969, 9.521520614624023, 9.336447715759277, 8.454047203063965, 17.307310104370117, 10.473440170288086, 12.572321891784668, 28.47010612487793, -21.293920516967773, -16.40287208557129, -20.102954864501953, 9.602380752563477, 4.475848197937012, 4.312952518463135, 14.805852890014648, -11.63718032836914, -20.96299171447754, 20.77239990234375, -23.584428787231445, -9.896231651306152, -33.301666259765625, 14.689837455749512, 24.640613555908203, 9.430448532104492, 5.226198196411133, 8.960444450378418, 22.60553741455078, 8.54898452758789, 3.012317419052124, -29.939327239990234, 26.632213592529297, 12.089072227478027, 13.142219543457031, 9.963829040527344, -11.910558700561523, -29.939979553222656, -12.580557823181152, 2.7631375789642334, 8.965936660766602, -3.7224068641662598, -3.7005867958068848, -31.616661071777344, 25.047452926635742, 13.722382545471191, 9.054862022399902, 10.068466186523438, 9.785688400268555, 12.196121215820312, -31.337074279785156, 11.617836952209473, -5.050657749176025, 4.5957255363464355, 10.195629119873047, 25.973949432373047, -15.483882904052734, -11.136631965637207, -38.810123443603516, -37.314048767089844, -22.234086990356445, -39.46818923950195, 23.548063278198242, -13.956497192382812, -32.335391998291016, -13.325700759887695, 17.45980453491211, -28.277822494506836, -16.350292205810547, -28.592784881591797, -12.254311561584473, -28.594266891479492, 8.17866039276123, -30.996807098388672, -14.385151863098145, -19.158262252807617, 14.833539009094238, -14.118986129760742, -39.807857513427734, 28.825111389160156, 29.487411499023438, -27.9965763092041, -13.100311279296875, -9.700074195861816, 33.61240768432617, -24.381919860839844, 6.386781692504883, 34.84086227416992, 12.468594551086426, -28.592988967895508, 25.43992042541504, 32.35030746459961, 7.83320426940918, 22.511491775512695, 8.452092170715332, 6.397183418273926, 14.474228858947754, 9.914347648620605, 27.194599151611328, -23.446109771728516, 14.71922779083252, 19.47922706604004, 6.176606178283691, 7.547853946685791, -32.715843200683594, -33.19981002807617, 8.464118003845215, -25.784053802490234, 29.12650489807129, -24.327848434448242, 31.571748733520508, -30.157705307006836, -39.80814743041992, -34.771358489990234, -27.548574447631836, -18.678762435913086, 4.845274448394775, -14.49985122680664, 30.698312759399414, -29.806243896484375, -28.071943283081055, 8.611235618591309, 12.106879234313965, 27.856889724731445, 28.105531692504883, 11.647112846374512, 6.394392967224121, -13.590805053710938, 7.24580717086792, 24.693283081054688, -37.68799591064453, -22.196035385131836, 29.31842041015625, -11.34012508392334, -38.93219757080078, -12.29486083984375, 11.718506813049316, -30.387454986572266, 3.253413438796997, 28.179035186767578, -35.9044075012207, -14.589357376098633, 5.310382843017578, 6.7766594886779785, -17.208621978759766, -18.07488250732422, -30.961013793945312, 23.84549903869629, 31.809642791748047, -20.054718017578125, 32.72951126098633, 4.713023662567139, 25.52175521850586, -21.617733001708984, -0.06055441498756409, 6.989712715148926, 3.1294116973876953, -25.368240356445312, 31.71950912475586, -10.398778915405273, -12.329266548156738, -3.9276959896087646, -9.694510459899902, -11.015701293945312, -28.580835342407227, -30.15862274169922, -1.7468153238296509, 0.09407834708690643, -40.968685150146484, 33.983394622802734, -23.55512046813965, -31.172611236572266, -30.158769607543945, -37.6628532409668, -41.41393280029297, 13.72209644317627, -11.90219783782959, -3.7646472454071045, -30.100257873535156, -38.60463333129883, 16.385746002197266, -39.13634490966797, -22.608760833740234, -38.597633361816406, -22.382780075073242, 29.901092529296875, -16.820323944091797, 0.16633769869804382, 14. ...

# %%
knn(dfComp)
# Out:
# [[ 39  11]
#  [ 30 112]]
#               precision    recall  f1-score   support
#
#           -1       0.57      0.78      0.66        50
#            1       0.91      0.79      0.85       142
#
#    micro avg       0.79      0.79      0.79       192
#    macro avg       0.74      0.78      0.75       192
# weighted avg       0.82      0.79      0.80       192

# %%
corrMat(dfComp)

# %%
gradent(dfComp)
# Out:
# [[ 35  21]
#  [ 17 119]]
#               precision    recall  f1-score   support
#
#           -1       0.67      0.62      0.65        56
#            1       0.85      0.88      0.86       136
#
#    micro avg       0.80      0.80      0.80       192
#    macro avg       0.76      0.75      0.76       192
# weighted avg       0.80      0.80      0.80       192

# %% [markdown]
# ## Redes

# %%
PCA(dfRedes)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfRedes)
# Out:
# <div id="453f0717-a15b-4147-aed4-348ab8285e92" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("453f0717-a15b-4147-aed4-348ab8285e92")) {
#     Plotly.newPlot("453f0717-a15b-4147-aed4-348ab8285e92", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [12.93144416809082, -5.967801570892334, -6.26055383682251, 8.891687393188477, -6.900408744812012, 16.393802642822266, -41.1588134765625, -7.090445518493652, 16.335054397583008, 17.330673217773438, 9.966598510742188, 10.659805297851562, -21.32238006591797, 13.304247856140137, 5.004230499267578, -38.20646667480469, 15.099522590637207, -10.865161895751953, 8.521865844726562, 0.3723938763141632, -6.031795501708984, 26.650625228881836, 21.847110748291016, -4.7242021560668945, 11.075971603393555, -4.808475494384766, -3.0166127681732178, 8.805207252502441, 14.037181854248047, 0.9315080046653748, 28.811355590820312, 21.11397361755371, 13.91823673248291, 28.335498809814453, 29.206684112548828, 28.109460830688477, 9.283668518066406, 18.10344886779785, 1.0528591871261597, 13.975720405578613, 25.87055778503418, 13.498407363891602, 18.274391174316406, 29.181638717651367, 6.884987831115723, 2.011319875717163, -8.44101333618164, -5.866580963134766, 30.740121841430664, 25.44287872314453, 27.129043579101562, -5.32786750793457, -8.88435173034668, -0.45628806948661804, 14.610041618347168, -7.333985805511475, 3.8174281120300293, 23.669301986694336, 21.628807067871094, 7.040041923522949, -6.4507927894592285, 11.206888198852539, -11.476366996765137, 13.747099876403809, 20.008485794067383, 4.047357559204102, 10.650763511657715, -3.612636089324951, 12.006609916687012, 3.9903745651245117, 9.351137161254883, 29.20296287536621, 32.778106689453125, -6.627796173095703, 18.43558692932129, -6.412502765655518, 7.1133856773376465, 20.827375411987305, 30.69359016418457, 30.740055084228516, 18.27760887145996, -6.084368705749512, -2.9477570056915283, 4.551708698272705, -8.21745491027832, -5.70473575592041, 28.42674446105957, 30.762338638305664, -4.621889114379883, 24.360578536987305, 24.640098571777344, -3.3019614219665527, -8.799215316772461, 10.6462984085083, 10.445575714111328, 14.670400619506836, 7.103459358215332, 26.1141357421875, 29.443872451782227, -4.679838180541992, 18.447423934936523, -11.493119239807129, 0.31598955392837524, 25.797229766845703, 9.325732231140137, 2.0396971702575684, 17.051349639892578, -6.0248703956604, 6.601858139038086, 11.646537780761719, 30.03577995300293, 29.00298500061035, 32.38629150390625, 29.29751968383789, 30.53839683532715, 30.43253517150879, 13.75648307800293, 11.388998985290527, 6.65998649597168, 16.969600677490234, -5.20426082611084, 32.74391174316406, 31.71368408203125, 17.49274253845215, -3.2751004695892334, 18.24079704284668, 23.3444766998291, -3.957648515701294, 18.30108070373535, 18.034177780151367, 19.120166778564453, 20.5511474609375, 31.787630081176758, 30.25282096862793, 18.8273868560791, 30.62723159790039, 10.253864288330078, 30.53048324584961, 31.66452407836914, 6.842831134796143, -2.188345432281494, 29.172561645507812, 10.752313613891602, -3.7043752670288086, 29.08237075805664, 20.669584274291992, 14.61943244934082, 30.1910343170166, 15.249305725097656, 30.754384994506836, 20.138734817504883, -2.583806276321411, 28.58880043029785, 13.436742782592773, 12.107073783874512, 13.106125831604004, 16.72614860534668, 29.275299072265625, 13.866047859191895, 8.752631187438965, 14.992194175720215, 34.265560150146484, 13.796185493469238, 11.005999565124512, 15.638130187988281, 30.41404914855957, 15.967512130737305, 32.24504089355469, 31.86598777770996, 20.704042434692383, 29.574512481689453, 32.47816467285156, 22.043930053710938, 16.27802848815918, 15.226746559143066, 31.52675437927246, 35.168601989746094, 31.036577224731445, 33.799705505371094, 28.56902503967285, 5.729527950286865, 32.640987396240234, 12.841166496276855, 13.822392463684082, 5.631155490875244, 21.2022705078125, 30.14608383178711, 31.14720916748047, 30.412214279174805, 19.13496208190918, 21.39497184753418, 14.670763969421387, 31.897518157958984, 12.299384117126465, 14.044550895690918, 18.58570671 ...

# %%
knn(dfRedes)
# Out:
# [[100   9]
#  [ 31  63]]
#               precision    recall  f1-score   support
#
#           -1       0.76      0.92      0.83       109
#            1       0.88      0.67      0.76        94
#
#    micro avg       0.80      0.80      0.80       203
#    macro avg       0.82      0.79      0.80       203
# weighted avg       0.82      0.80      0.80       203

# %%
corrMat(dfRedes)

# %% [markdown]
# ## Mec

# %%
PCA(dfMec)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfMec)
# Out:
# <div id="a8d92fc3-a04c-4fde-b092-496b4d74bf23" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a8d92fc3-a04c-4fde-b092-496b4d74bf23")) {
#     Plotly.newPlot("a8d92fc3-a04c-4fde-b092-496b4d74bf23", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [-32.81382751464844, -38.77341079711914, -26.54684829711914, -29.809988021850586, -49.0910758972168, -47.9208869934082, -50.00580978393555, -49.12065124511719, -51.72634506225586, -51.64419174194336, -25.988143920898438, -48.78213882446289, -48.618778228759766, -48.31863021850586, -48.98247528076172, -51.515480041503906, -48.19705581665039, -28.875865936279297, -25.627731323242188, -21.83997917175293, 12.757505416870117, -39.43503189086914, -44.75956344604492, -29.023601531982422, -38.31869125366211, -51.42945098876953, -45.39826965332031, -31.36872100830078, -37.818660736083984, -40.56303405761719, -53.32346725463867, -45.6427001953125, -48.8881950378418, -14.040237426757812, -29.076744079589844, -41.78300094604492, -29.353878021240234, -43.95103454589844, -42.73046112060547, -40.82673645019531, -50.90506362915039, -37.18721008300781, -40.06998825073242, -24.872285842895508, -51.25364685058594, -25.31595230102539, -30.873149871826172, -53.415592193603516, -42.07029342651367, -46.60832595825195, -24.357677459716797, -53.13446044921875, -34.708126068115234, -24.342050552368164, -42.608238220214844, -36.26294708251953, -44.87318420410156, -46.06996154785156, -24.222322463989258, 16.104379653930664, -42.334529876708984, -45.32829284667969, -40.11696243286133, -50.01957702636719, -24.793983459472656, -42.3717155456543, -35.34981918334961, -5.369627475738525, 1.4686927795410156, 0.9353185296058655, 37.05479049682617, -1.2102316617965698, -1.732695460319519, -1.454583764076233, 6.746585369110107, 39.05233383178711, -0.858128547668457, 0.7237476706504822, -1.5637027025222778, 38.3967170715332, 3.189859628677368, 42.08884811401367, 41.50764083862305, -1.2067363262176514, 5.882955551147461, 40.77218246459961, 34.31566619873047, 4.86832332611084, 34.62077331542969, 4.204355716705322, 24.781414031982422, 37.71699142456055, -1.6981775760650635, 30.393266677856445, 0.9343627095222473, 4.696471214294434, 9.278054237365723, -3.022571325302124, 31.732086181640625, 3.3099732398986816, 32.08602523803711, 31.161090850830078, -5.12640905380249, 41.193870544433594, 3.7160298824310303, 4.6406569480896, 41.419673919677734, 33.161048889160156, 1.3790998458862305, 9.859021186828613, 1.1711119413375854, 36.58749008178711, 33.786651611328125, 38.877784729003906, -2.663241386413574, -0.0225268192589283, 10.2711820602417, 0.1687912493944168, 37.86674880981445, 36.69905471801758, 37.77556228637695, -2.235085964202881, 19.80275535583496, 1.6852848529815674, 32.84944152832031, 2.242222785949707, 0.9545323252677917, -2.633431911468506, -0.876128613948822, 16.452817916870117, -4.91017484664917, 39.11203384399414, -0.3598952293395996, 38.2457275390625, -3.1856470108032227, -3.9862537384033203, 40.74311828613281, 16.39746856689453, 0.9639079570770264, 33.32878112792969, 33.485897064208984, 37.49790954589844, -1.100091576576233, 37.178462982177734, -4.289863586425781, -3.0982632637023926, 1.2331777811050415, 0.07768920809030533, -3.5157039165496826, 40.98134231567383, 31.316083908081055, 39.29005813598633, 38.053157806396484, 37.41780090332031, 36.402923583984375, -0.7657766938209534, 38.8637580871582, 29.324798583984375, 10.008200645446777, -15.86880111694336, 1.4577564001083374, -4.016343593597412, -1.6734102964401245, -0.9375402927398682, -0.4239155650138855, 34.419769287109375, 35.68069076538086, 11.549593925476074, -0.8036309480667114, -0.040444888174533844, 39.49094772338867, 34.590824127197266, -4.383508682250977, 30.25417137145996, -11.356704711914062, 2.152299642562866, 0.5092216730117798, -0.019057154655456543, -15.926742553710938, -3.8954901695251465, 31.632308959960938, 15.395307540893555, -3.212172746658325, 40.37055587768555, -2.5242817401885986, -0.4725148677825928, -1.611335277557373, 30.30373191833496, 14.16484546661377, 36.12945556640625, 36.034339904785156, 1.8320550918579102, -0.7098 ...

# %%
knn(dfMec)
# Out:
# [[95  4]
#  [32 49]]
#               precision    recall  f1-score   support
#
#           -1       0.75      0.96      0.84        99
#            1       0.92      0.60      0.73        81
#
#    micro avg       0.80      0.80      0.80       180
#    macro avg       0.84      0.78      0.79       180
# weighted avg       0.83      0.80      0.79       180

# %%
corrMat(dfMec)

# %% [markdown]
# # CIC

# %%
PCA(dfCic)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfCic)
# Out:
# <div id="fcc2ca37-3505-40ba-9771-7a90a0282142" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("fcc2ca37-3505-40ba-9771-7a90a0282142")) {
#     Plotly.newPlot("fcc2ca37-3505-40ba-9771-7a90a0282142", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [9.473076820373535, 12.611115455627441, 19.605327606201172, 6.474536418914795, 24.077146530151367, 6.677761077880859, 15.297914505004883, 10.260247230529785, 2.4453976154327393, 5.519529819488525, -18.475393295288086, -19.72885513305664, -35.03056335449219, -35.20845031738281, 6.636882781982422, -16.83244514465332, 34.75270462036133, 28.463504791259766, 4.962278842926025, 36.62820816040039, 44.71559143066406, 44.80155563354492, 52.646671295166016, 47.04620361328125, 23.29703712463379, 5.324360370635986, 44.82135009765625, 19.50115966796875, 48.071170806884766, 18.778385162353516, 46.74589157104492, 48.60390090942383, 18.459585189819336, 47.098548889160156, 46.90222930908203, 44.914581298828125, 45.44520568847656, 35.35910415649414, 45.47254943847656, 48.408203125, 48.588905334472656, 24.052553176879883, 37.74814224243164, 47.74079132080078, 49.76580047607422, 48.20028305053711, 46.818450927734375, 23.365930557250977, 43.86635971069336, -21.545957565307617, 44.949485778808594, 46.616355895996094, 50.23942184448242, 40.063270568847656, 47.60804748535156, 40.0820198059082, 26.395715713500977, 34.14577102661133, 32.68159103393555, -56.81444549560547, 37.04118347167969, 43.90575408935547, 46.55708312988281, 38.42249298095703, 46.01218032836914, 15.481255531311035, 17.707834243774414, 44.143165588378906, 41.099510192871094, 38.191219329833984, 42.719112396240234, 35.95808410644531, 22.43154525756836, 42.272674560546875, 49.37453079223633, 43.224422454833984, 43.01103591918945, 32.775733947753906, 36.7780876159668, 32.60081481933594, 43.08094024658203, 23.8266544342041, 45.94330596923828, 42.71029281616211, 44.258365631103516, 25.6923885345459, 33.162715911865234, -17.544153213500977, 41.59492111206055, 38.643218994140625, 49.746822357177734, 47.027740478515625, 45.9091682434082, 46.40700149536133, 44.50192642211914, -24.462013244628906, 43.20473098754883, 43.782962799072266, 47.85883331298828, 49.199398040771484, -32.220489501953125, 49.393028259277344, 28.86673927307129, 21.667407989501953, 26.581897735595703, 40.137020111083984, 44.40997314453125, 51.180179595947266, 51.07961654663086, 22.31658172607422, 40.13542938232422, 41.15928649902344, 35.644775390625, 42.529422760009766, 22.959447860717773, 36.20178985595703, 39.07233810424805, 25.313690185546875, 50.52467346191406, -17.48223114013672, 26.54193115234375, 36.34135818481445, 23.271991729736328, 23.26746940612793, 41.44271469116211, 22.91543197631836, 42.92401123046875, 50.563087463378906, 21.9591007232666, 37.20457458496094, 34.61207962036133, 21.91441535949707, 39.1840705871582, 40.63920974731445, 24.43279457092285, 48.615657806396484, 24.49051856994629, 34.51967239379883, -19.2067813873291, 49.63195037841797, 0.290973037481308, 23.828012466430664, 24.750747680664062, 28.362342834472656, 48.83325958251953, 50.530982971191406, 47.204341888427734, 46.93855285644531, 46.46712112426758, 47.832401275634766, 24.596059799194336, -36.66875457763672, -34.52566146850586, 47.68608856201172, -19.382503509521484, 43.07920455932617, 51.03795623779297, 44.080078125, 23.041641235351562, -19.94870948791504, 20.28251075744629, 11.581064224243164, -53.720333099365234, 34.24601745605469, 45.893341064453125, -53.72056579589844, 24.458703994750977, 19.80803108215332, 36.64899826049805, 43.27073287963867, 30.81195640563965, 34.00916290283203, 47.175498962402344, 42.342933654785156, -54.48786163330078, 33.932708740234375, 43.68403244018555, 37.62823486328125, 48.96245193481445, 36.48919677734375, 18.905651092529297, 35.53413772583008, 40.41413879394531, 48.292808532714844, 26.025407791137695, 33.52683639526367, -28.288393020629883, -35.424537658691406, 46.46798324584961, -53.07609558105469, 24.860984802246094, 44.71807098388672, 31.724441528320312, 39.63323211669922, 37.97792053222656, 21.561649322509766, 35.66320037841797, 19.69412422180 ...

# %%
knn(dfCic)
# Out:
# [[154   5]
#  [ 48 103]]
#               precision    recall  f1-score   support
#
#           -1       0.76      0.97      0.85       159
#            1       0.95      0.68      0.80       151
#
#    micro avg       0.83      0.83      0.83       310
#    macro avg       0.86      0.83      0.82       310
# weighted avg       0.86      0.83      0.83       310

# %%
corrMat(dfCic)

# %% [markdown]
# # Eng

# %%
PCA(dfEng)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfEng)
# Out:
# <div id="3fe97e8d-d40b-490b-b9b7-af9970a37e35" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("3fe97e8d-d40b-490b-b9b7-af9970a37e35")) {
#     Plotly.newPlot("3fe97e8d-d40b-490b-b9b7-af9970a37e35", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "0", "x": [-23.7069149017334, 4.332490921020508, 5.103934288024902, 4.8167243003845215, 7.928695201873779, 6.499233722686768, 6.684390544891357, 7.02523946762085, 14.334053039550781, -22.605609893798828, 18.278221130371094, -1.288607120513916, 9.154818534851074, 2.06769061088562, 19.390438079833984, 18.701692581176758, 6.158303737640381, -24.351301193237305, 5.409844875335693, 9.678889274597168, 6.367004871368408, -2.9931724071502686, 1.2886193990707397, 6.61876106262207, 0.14277483522891998, 2.9789719581604004, 1.647689700126648, 7.660922527313232, 14.604010581970215, -0.14691224694252014, 4.8803839683532715, 6.134881019592285, 8.710813522338867, -0.5511248111724854, 0.6865164637565613, -3.365017890930176, 6.222395420074463, 14.091716766357422, 19.489673614501953, 7.632421016693115, 4.929417133331299, 1.469407320022583, 14.19723129272461, 11.190239906311035, -19.387386322021484, 6.286062240600586, -0.2628471553325653, 9.565168380737305, 20.7153377532959, 11.303936004638672, 19.438974380493164, -0.8846039772033691, 7.89915132522583, 5.33565616607666, 18.619508743286133, 16.514692306518555, -0.6953569054603577, -0.3340609669685364, 5.055525302886963, 10.408052444458008, 12.849739074707031, -2.622083902359009, 8.243237495422363, 9.40078353881836, 9.589007377624512, -21.05963706970215, 0.27204430103302, 9.87313461303711, 1.3816752433776855, 10.539594650268555, 16.179166793823242, 12.212857246398926, 7.922431945800781, 8.812128067016602, 4.577502250671387, 6.961667060852051, 7.028491497039795, 4.085006237030029, -17.970266342163086, -2.5838871002197266, 22.73843765258789, 8.569191932678223, 0.9562366008758545, 1.3887633085250854, 19.73812484741211, 1.8321211338043213, 8.942353248596191, -6.746296405792236, 7.628236770629883, 19.754535675048828, 2.694633722305298, -1.3117852210998535, 0.5123100876808167, 0.060163699090480804, 10.651032447814941, 1.817202091217041, 13.37768268585205, 7.469062328338623, -23.712526321411133, 22.03569984436035, 8.216817855834961, -23.111061096191406, 7.148908615112305, 4.967745304107666, 14.171452522277832, 8.878947257995605, -0.5677405595779419, 13.319600105285645, 2.8943917751312256, 5.46821403503418, 11.858264923095703, 1.4046329259872437, 13.614151000976562, 0.3192502558231354, 6.587062358856201, -8.543710708618164, -4.221165657043457, -0.5055556297302246, 5.566067695617676, 2.128624677658081, 8.242210388183594, 8.090901374816895, 8.473186492919922, 10.637765884399414, 10.577596664428711, 15.544964790344238, 15.703176498413086, 7.785879611968994, 9.085551261901855, 8.47282886505127, 13.319840431213379, -2.482348918914795, -18.148868560791016, 5.534726619720459, 9.823049545288086, 14.215438842773438, 20.286155700683594, -6.848987102508545, 21.386507034301758, 11.20881462097168, 20.054298400878906, 0.6789731383323669, 7.664185047149658, 13.889470100402832, 17.051998138427734, 7.555007457733154, 9.246569633483887, 11.050493240356445, 20.425914764404297, 20.63667106628418, 17.62325096130371, 19.355501174926758, 7.963494777679443, 13.12557601928711, 20.515535354614258, -0.7314780354499817, 8.630064010620117, 14.602556228637695, 11.066350936889648, -6.3256049156188965, 8.3212251663208, -14.094659805297852, 3.1705360412597656, 6.404407501220703, 8.815425872802734, 10.074342727661133, 1.5547816753387451, 21.826976776123047, 20.915571212768555, 2.2132506370544434, 6.610091209411621, 6.834090232849121, 12.863179206848145, 12.5897216796875, 7.509994029998779, 6.867941856384277, -0.5393980741500854, 21.28923797607422, -2.097405195236206, 7.365018367767334, 11.490772247314453, 14.836589813232422, 4.772539138793945, -8.8062162399292, 13.173192977905273, -6.481582164764404, -0.4269644320011139, -2.2569873332977295, 11.891979217529297, -6.644624710083008, -4.358551025390625, 1.6621495485305786, 11.798076629638672, 13.746088981628418, 12.87353515625, -0.505771636962 ...

# %%
knn(dfEng)
# Out:
# [[11  0]
#  [ 5 25]]
#               precision    recall  f1-score   support
#
#           -1       0.69      1.00      0.81        11
#            1       1.00      0.83      0.91        30
#
#    micro avg       0.88      0.88      0.88        41
#    macro avg       0.84      0.92      0.86        41
# weighted avg       0.92      0.88      0.88        41

# %%
corrMat(dfEng)
