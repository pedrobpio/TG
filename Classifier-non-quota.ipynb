# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.manifold import TSNE

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# df = pd.read_csv("teste.csv", index_col=0)

# %%
# df[df['ID Aluno']==208149] #id

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.offline as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # preparing data

# %%
primeiroCiC = ['116301', '118001', '118010', '113034', '140481', '145971']
segundoCiC = ['116319', '115045', '118028', '118036', '113042']
terceiroCiC = ['118044', '118052', '113956', '113051', '117366']


primeiroLic1 =['116793', '117366', '145971', '147389', '194221']
segundoLic1 = ['113034', '116301', '125156']
terceiroLic1 = ['115045', '116319', '125172']

primeiroLic2 =['113492', '194221', '113450', '113476']
segundoLic2 = ['113034', '116319', '191027', '150649', '194280']
terceiroLic2 = ['115045', '113093', '117366', '117889']

primeiroEngComp =['113034', '113093', '113476', '117528', '118001', '118010']
segundoEngComp = ['118028', '118036', '113042', '115045', '116319']
terceiroEngComp =['113051', '117242', '170054', '201600', '206075']


primeiroMec = ['114626', '114634', '118010', '113476', '113034', '118001', '168891']
segundoMec = ['168891', '113093', '118028', '118036', '115045', '168874']
terceiroMec = ['113051', '118044', '118052', '168769', '116319']

primeiroRedes = ['113034', '113093', '118001', '118010', '167959']
segundoRedes = ['113042', '115045', '118028', '118036', '169676']
terceiroRedes = ['113051', '113301', '167983', '169749']


undropableCol = ["curso","saiu","Cotista","Raça","Sexo","Tipo de Escola"]#, 'Ingresso_unb'

# %%
df0 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_0.csv", index_col=0)
df1 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_1.csv", index_col=0)
df2 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_2.csv", index_col=0)
df3 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_3.csv", index_col=0)
df4 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_4.csv", index_col=0)
df5 = pd.read_csv("aluno_quant_Materias_Media_nao_cotistas_5.csv", index_col=0)

# %%
dfComp = df0[undropableCol+primeiroLic1+segundoLic1+terceiroLic1].fillna(-1)
dfRedes = df1[undropableCol+primeiroRedes+segundoRedes+terceiroRedes].fillna(-1)
dfCic = df2[undropableCol+primeiroCiC+segundoCiC+terceiroCiC].fillna(-1) 
dfMec = df3[undropableCol+primeiroMec+segundoMec+terceiroMec].fillna(-1) 
dfEng = df4[undropableCol+primeiroEngComp+segundoEngComp+terceiroEngComp].fillna(-1)

# %% [markdown]
# # PCA

# %%
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)

# %%
def PCA (df, currentLabel = 'saiu'):
    data = (
        df

    )
    
    x = data.iloc[:].values
    y = data[currentLabel].values

    data[currentLabel]
    numColors = len(data[currentLabel].unique())

    sklearn_pca = sklearnPCA(n_components=2)

    Y_sklearn = sklearn_pca.fit_transform(x)

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    with plt.style.context('seaborn-whitegrid'):
        plt.figure(figsize=(15, 10))
        for lab, col in zip(data[currentLabel].unique(),
                            colorList):
            plt.scatter(Y_sklearn[y==lab, 0],
                        Y_sklearn[y==lab, 1],
                        label=lab,
                        c=col)
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend(loc='lower right')
        plt.tight_layout()
        plt.show()

    plt.show()

# %% [markdown]
# # TSNE

# %%
def formatColor(color):
    return 'rgb('+str(int(color[0]*255))+','+str(int(color[1]*255))+','+str(int(color[2]*255))+')'

    
def tsne(df, currentLabel = 'saiu'):
    a = df
    X = a.values
    X_embedded = TSNE(n_components=2).fit_transform(X)
    
    
    data = a
    Y_sklearn = X_embedded
    y = data[currentLabel].values
    numColors = len(data[currentLabel].unique())

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    traceArr = []
    for lab, col in zip(data[currentLabel].unique(),
                        colorList):
        
        trace1 = go.Scatter(
            x=Y_sklearn[y==lab, 0],
            y=Y_sklearn[y==lab, 1],
#             z=Y_sklearn[y==lab, 2],
            mode='markers',
            name = str(lab),
            marker=dict(
                size=5,
                color=formatColor(col),
                opacity=0.8
            )
        )
        traceArr.append(trace1)

    data = traceArr
    layout = go.Layout(
        margin=dict(
            l=0,
            r=0,
            b=0,
            t=0
        )
    )
    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, filename='3d-scatter-colorscale')

# %%
# draw2dFrame(a, X_embedded, 'saiu')

# %% [markdown]
# # knn

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# a = a[a["saiu"]!=0]
# y = a["saiu"]
# X = a.drop(["saiu"], axis = 1)

# %%
def knn (df, currentLabel = 'saiu'):
    a = df[df[currentLabel]!=0]
    y = a[currentLabel]
    X = a.drop([currentLabel], axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35)
    scaler = StandardScaler()  
    scaler.fit(X_train)

    X_train = scaler.transform(X_train)  
    X_test = scaler.transform(X_test)  
    
    classifier = KNeighborsClassifier(n_neighbors=2)  
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    
    print(confusion_matrix(y_test, y_pred))  
    print(classification_report(y_test, y_pred))

# %%
# scaler = StandardScaler()  
# scaler.fit(X_train)

# X_train = scaler.transform(X_train)  
# X_test = scaler.transform(X_test)

# %%
# classifier = KNeighborsClassifier(n_neighbors=2)  
# classifier.fit(X_train, y_train)
# y_pred = classifier.predict(X_test)

# %%
 
# print(confusion_matrix(y_test, y_pred))  
# print(classification_report(y_test, y_pred))
# knn(X, y)

# %%
# a

# %% [markdown]
# ## Comp

# %%
PCA(dfComp)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfComp)
# Out:
# <div id="221e5521-9ffb-4f64-b2aa-3568dea71c8c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("221e5521-9ffb-4f64-b2aa-3568dea71c8c")) {
#     Plotly.newPlot("221e5521-9ffb-4f64-b2aa-3568dea71c8c", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [28.215923309326172, 21.05536460876465, 22.186054229736328, 32.05937194824219, 24.678321838378906, 19.342710494995117, 18.07707977294922, 13.735815048217773, 13.028366088867188, 2.1764047145843506, 21.450510025024414, 21.182350158691406, 15.772034645080566, -14.902027130126953, -31.209102630615234, -14.160209655761719, 8.906004905700684, 28.069215774536133, 27.866235733032227, 10.919336318969727, -15.491568565368652, -15.371091842651367, 21.892765045166016, -22.464542388916016, -3.3931877613067627, -26.554040908813477, 27.729528427124023, 30.84581184387207, 23.558557510375977, 17.742414474487305, 22.23138999938965, 32.8770637512207, 17.275545120239258, -2.070957899093628, -24.689334869384766, 35.77549362182617, 22.637304306030273, 27.666414260864258, 14.991476058959961, -16.98396873474121, -24.689952850341797, -33.92324447631836, -2.0947794914245605, 18.319828033447266, -11.237955093383789, -11.193832397460938, -29.515003204345703, 39.33179473876953, 25.63629722595215, 23.70914649963379, 26.537105560302734, 25.571990966796875, 15.15489673614502, -36.896278381347656, 14.706242561340332, -9.118697166442871, 18.164323806762695, 8.47812271118164, 31.428985595703125, -37.94728088378906, -16.716678619384766, -34.84468078613281, -33.20465087890625, -20.852848052978516, -35.30274963378906, 30.823169708251953, -17.799970626831055, -30.45941925048828, -17.75252914428711, 26.445945739746094, -21.735584259033203, -30.76852798461914, -25.704200744628906, -17.345502853393555, -25.706069946289062, 19.59334945678711, -36.67396545410156, -18.19498634338379, -5.817115306854248, 19.217100143432617, -35.426753997802734, -34.113948822021484, 36.89071273803711, 46.19242477416992, -29.063533782958984, -16.511390686035156, -28.008831024169922, 34.040077209472656, -38.458717346191406, 1.8056148290634155, 35.30875015258789, 20.29413414001465, -25.704547882080078, 39.619850158691406, 32.90379333496094, 17.80975341796875, 24.35527229309082, 11.308857917785645, 2.3973474502563477, 18.63912010192871, -3.1829583644866943, 34.860084533691406, -19.544231414794922, 18.973094940185547, 21.995784759521484, 1.7036820650100708, 2.81229567527771, -25.438133239746094, -28.614425659179688, 17.100406646728516, -21.379934310913086, 37.06722640991211, -9.163795471191406, 34.14323043823242, -27.699016571044922, -34.11511993408203, -40.21845626831055, -23.394947052001953, -4.057121753692627, 1.659525752067566, -17.748851776123047, 39.39008331298828, -26.94564437866211, -25.589433670043945, 4.88746452331543, 19.497398376464844, 43.6275749206543, 35.7578239440918, 16.511777877807617, 2.895981788635254, -8.364707946777344, 2.7543346881866455, 39.14216232299805, -29.495086669921875, -7.5110087394714355, 46.00165939331055, 3.2145309448242188, -32.94478225708008, -28.169509887695312, 14.612781524658203, -31.597850799560547, -0.13297681510448456, 44.683143615722656, -31.574962615966797, -36.73421096801758, 0.5778967142105103, 13.558870315551758, -31.66852569580078, -3.947122812271118, -23.436809539794922, 37.96228790283203, 35.69615936279297, -4.7370781898498535, 33.60911178588867, -0.028436463326215744, 10.16768741607666, -15.590882301330566, 20.07331657409668, 13.7368745803833, 4.090828895568848, -21.107057571411133, 36.19472885131836, -5.841510772705078, -7.755241394042969, 4.820822238922119, -4.984311103820801, -6.0735087394714355, -29.65559196472168, -27.793838500976562, 8.783010482788086, 0.9401648044586182, -42.016319274902344, 34.68037033081055, -16.98296356201172, -28.33402442932129, -27.707374572753906, -32.2139892578125, -32.55390548706055, 11.481245040893555, -7.048944473266602, 4.921306133270264, -28.4547176361084, -34.32855987548828, 21.260637283325195, -34.279273986816406, -15.935791015625, -35.11895751953125, -15.844711303710938, 30.413036346435547, -34.652427673339844, 1.9507248401641846, 18.15907287597 ...

# %%
knn(dfComp)
# Out:
# [[ 73  19]
#  [ 41 203]]
#               precision    recall  f1-score   support
#
#           -1       0.64      0.79      0.71        92
#            1       0.91      0.83      0.87       244
#
#    micro avg       0.82      0.82      0.82       336
#    macro avg       0.78      0.81      0.79       336
# weighted avg       0.84      0.82      0.83       336
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ## Redes

# %%
PCA(dfRedes)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfRedes)
# Out:
# <div id="d129fb56-9d8e-4103-9091-eb32a2a20e1b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("d129fb56-9d8e-4103-9091-eb32a2a20e1b")) {
#     Plotly.newPlot("d129fb56-9d8e-4103-9091-eb32a2a20e1b", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [-11.581754684448242, 17.2520809173584, 17.152793884277344, -8.486233711242676, 18.25238800048828, -17.7323055267334, 35.99360275268555, 18.40146255493164, -17.548538208007812, -13.842413902282715, -8.052299499511719, -9.321027755737305, 17.534183502197266, -13.737439155578613, -1.683138132095337, 34.996185302734375, -18.102537155151367, 26.893070220947266, -9.141695022583008, 15.245945930480957, 17.170501708984375, -26.59186363220215, -23.290937423706055, 4.19211483001709, -9.459015846252441, 4.90716552734375, 3.4024553298950195, -9.426437377929688, -12.958907127380371, -3.7672908306121826, -28.85722541809082, -22.57120132446289, -19.932464599609375, -28.35989761352539, -29.229719161987305, -28.949100494384766, -9.893561363220215, -19.00191307067871, -1.2714521884918213, -19.653491973876953, -25.863943099975586, -12.158878326416016, -19.111953735351562, -30.153017044067383, -7.406458854675293, -2.857330083847046, 18.285037994384766, 3.1463124752044678, -31.005380630493164, -25.309476852416992, -27.10626792907715, 5.850382328033447, 6.311580181121826, -1.483230471611023, -15.020606994628906, 4.3415350914001465, -3.8663179874420166, -23.2685489654541, -22.129196166992188, -4.787965774536133, 4.304207801818848, -9.433687210083008, 25.750080108642578, -17.481571197509766, -21.941722869873047, -4.232625961303711, -8.829536437988281, 3.966603994369507, -10.32030963897705, -3.896218776702881, -10.028112411499023, -29.749191284179688, -33.72469711303711, 4.300780296325684, -19.60690689086914, 4.317562103271484, -5.95954704284668, -22.130531311035156, -30.93923568725586, -31.005319595336914, -15.594399452209473, 13.060415267944336, 1.7010104656219482, -24.256662368774414, 6.606058597564697, 4.229620456695557, -28.322603225708008, -30.98695945739746, 3.8362679481506348, -24.44314193725586, -24.569677352905273, 2.2545602321624756, 6.554285049438477, -8.834606170654297, -10.121406555175781, -16.348777770996094, -4.848020553588867, -26.101423263549805, -29.319963455200195, 5.204444885253906, -17.50551414489746, 24.41888427734375, 5.1076178550720215, -25.705808639526367, -6.310769557952881, -2.4013445377349854, -14.531871795654297, 2.3541438579559326, -6.56328010559082, -9.087340354919434, -30.236316680908203, -29.249300003051758, -32.64464569091797, -30.21729850769043, -31.499156951904297, -31.390457153320312, -18.6955623626709, -9.720846176147461, -2.6705024242401123, -14.000181198120117, 3.412269353866577, -33.68424987792969, -31.965991973876953, -16.905006408691406, 1.9686938524246216, -15.267525672912598, -20.1186466217041, 3.8480453491210938, -18.33686637878418, -14.482964515686035, -21.306673049926758, -21.13543701171875, -32.53349304199219, -30.520565032958984, -18.430923461914062, -30.83287239074707, -11.382750511169434, -30.766359329223633, -31.93036460876465, -6.944797039031982, -15.9131498336792, -30.12004852294922, -11.371598243713379, 2.331636905670166, -29.984268188476562, -16.350431442260742, -12.64259147644043, -30.940664291381836, -14.828429222106934, -31.02132225036621, -18.744165420532227, 2.246891975402832, -29.456863403320312, -16.631427764892578, -11.090652465820312, -11.376262664794922, -17.613622665405273, -29.51186752319336, -14.839761734008789, -8.353253364562988, -16.72165298461914, -34.445491790771484, -16.795568466186523, -9.082928657531738, -17.193784713745117, -30.6390380859375, -17.449769973754883, -32.52237319946289, -32.1484489440918, -19.41803550720215, -30.519954681396484, -32.611351013183594, -22.646596908569336, -17.33200454711914, -16.15700912475586, -31.788196563720703, -35.36937713623047, -31.260631561279297, -33.9636116027832, -28.785938262939453, -3.649409294128418, -32.766422271728516, -11.835628509521484, -13.37619686126709, -5.7196269035339355, -21.810701370239258, -30.398557662963867, -31.820770263671875, -30.711305618286133, -18.514 ...

# %%
knn(dfRedes)
# Out:
# [[198   9]
#  [ 57  91]]
#               precision    recall  f1-score   support
#
#           -1       0.78      0.96      0.86       207
#            1       0.91      0.61      0.73       148
#
#    micro avg       0.81      0.81      0.81       355
#    macro avg       0.84      0.79      0.80       355
# weighted avg       0.83      0.81      0.81       355
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ## Mec

# %%
PCA(dfMec)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfMec)
# Out:
# <div id="4b34e220-f0ce-4e92-8b77-679d0af23104" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("4b34e220-f0ce-4e92-8b77-679d0af23104")) {
#     Plotly.newPlot("4b34e220-f0ce-4e92-8b77-679d0af23104", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [-30.0634765625, -34.191184997558594, -28.69823455810547, -34.05788803100586, -48.1572151184082, -46.82861328125, -47.49897384643555, -48.70616912841797, -46.57843780517578, -49.3662109375, -22.813987731933594, -48.817359924316406, -45.968238830566406, -46.74834442138672, -47.731544494628906, -46.385623931884766, -47.59812927246094, -30.803085327148438, -29.233348846435547, -19.314485549926758, 1.5635125637054443, -38.64653396606445, -42.21623611450195, -30.768146514892578, -38.192726135253906, -43.90105056762695, -45.496891021728516, -31.984539031982422, -34.8933219909668, -38.78886795043945, -45.59560775756836, -43.78305435180664, -45.50977325439453, -14.779112815856934, -27.6140079498291, -34.143150329589844, -33.106571197509766, -40.827266693115234, -38.951751708984375, -34.268253326416016, -44.73017501831055, -35.818031311035156, -34.15641403198242, -26.791154861450195, -45.270538330078125, -22.943641662597656, -28.943174362182617, -44.37957000732422, -32.451316833496094, -44.369136810302734, -22.72052001953125, -44.8207893371582, -35.71457290649414, -26.108354568481445, -35.24531173706055, -33.611637115478516, -39.57748031616211, -40.310142517089844, -21.146350860595703, 1.6050665378570557, -31.330965042114258, -37.770565032958984, -39.84810256958008, -44.25016403198242, -20.789133071899414, -31.292282104492188, -36.69469451904297, 39.965267181396484, 32.474578857421875, 32.00652313232422, 9.859480857849121, 43.920475006103516, 45.55500793457031, 43.29423522949219, 33.95733642578125, 12.100175857543945, 34.76777648925781, 36.952877044677734, 42.6812629699707, 11.105701446533203, 39.3603630065918, 10.600251197814941, 10.286545753479004, 43.895233154296875, 37.93263626098633, 11.002931594848633, 11.45622444152832, 37.33565139770508, 10.92506217956543, 36.088768005371094, 16.6570987701416, 13.540910720825195, 45.46522903442383, 13.851152420043945, 36.8372802734375, 37.30535125732422, 28.264108657836914, 44.339534759521484, 3.639737606048584, 35.13124465942383, 10.242121696472168, 3.9673075675964355, 39.79359817504883, 11.260564804077148, 36.05342483520508, 36.51396179199219, 10.471687316894531, 10.029281616210938, 32.52019119262695, 2.3427295684814453, 32.6171989440918, 13.202383041381836, 15.143000602722168, 13.039715766906738, 35.696624755859375, 37.541473388671875, 33.134281158447266, 34.83087921142578, 3.0379388332366943, 11.651516914367676, 3.0286600589752197, 36.27702713012695, 22.203935623168945, 34.39827346801758, 9.168535232543945, 35.17375946044922, 36.93876647949219, 35.83271026611328, 42.175106048583984, 3.4507715702056885, 40.159698486328125, 11.117046356201172, 43.24760437011719, 5.665093421936035, 35.59468460083008, 34.66246032714844, 10.649842262268066, 3.88358736038208, 33.45261001586914, 9.172297477722168, 4.785367012023926, 5.329139232635498, 43.84168243408203, 5.189511775970459, 41.861175537109375, 34.671302795410156, 36.22765350341797, 36.573577880859375, 38.02682876586914, 11.694937705993652, 9.048136711120605, 3.061439037322998, 10.698041915893555, 10.419160842895508, 9.719813346862793, 38.4835090637207, 11.816983222961426, 15.43980884552002, 28.466163635253906, -22.615793228149414, 36.830326080322266, 42.42285919189453, 35.20936584472656, 34.60495376586914, 35.288917541503906, 7.865725040435791, 10.870750427246094, 5.270529747009277, 33.642662048339844, 40.27269744873047, 5.640078544616699, 11.790304183959961, 42.673431396484375, 9.747720718383789, -12.783681869506836, 35.712337493896484, 32.453399658203125, 40.17557144165039, -22.658008575439453, 38.881710052490234, 10.585474967956543, 13.020013809204102, 44.889434814453125, 9.691136360168457, 45.03178024291992, 38.537925720214844, 40.80665969848633, 8.167783737182617, 5.5189056396484375, 13.416330337524414, 11.780213356018066, 31.770854949951172, 41.98793029785156, 32.387054443359375, 14. ...

# %%
knn(dfMec)
# Out:
# [[162   9]
#  [ 47  97]]
#               precision    recall  f1-score   support
#
#           -1       0.78      0.95      0.85       171
#            1       0.92      0.67      0.78       144
#
#    micro avg       0.82      0.82      0.82       315
#    macro avg       0.85      0.81      0.81       315
# weighted avg       0.84      0.82      0.82       315
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# # CIC

# %%
PCA(dfCic)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfCic)
# Out:
# <div id="8bc23fec-93df-476d-bace-db4778ff3530" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("8bc23fec-93df-476d-bace-db4778ff3530")) {
#     Plotly.newPlot("8bc23fec-93df-476d-bace-db4778ff3530", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [-60.19829559326172, -43.68061447143555, -58.517948150634766, -45.26709747314453, 6.541518211364746, -37.96455001831055, -38.51429748535156, -43.18282699584961, -31.483779907226562, -29.70711898803711, 8.135533332824707, 8.516104698181152, 27.392759323120117, 28.28433609008789, -38.50712966918945, 1.1615086793899536, -19.30839729309082, 8.34697437286377, -42.986907958984375, -21.35602378845215, -17.97918128967285, -19.170757293701172, -28.375938415527344, -20.317626953125, -37.03437042236328, -44.33679962158203, -18.01967430114746, -52.16645431518555, -21.382112503051758, -53.71978759765625, -21.140804290771484, -22.294029235839844, 11.023955345153809, -21.004621505737305, -21.0625, -17.704761505126953, -19.702972412109375, -21.008615493774414, -23.147560119628906, -24.374292373657227, -24.14664649963379, 6.554050445556641, -28.221773147583008, -24.100051879882812, -25.00988006591797, -25.087726593017578, -23.625614166259766, -37.31575012207031, -24.1556453704834, 10.029647827148438, -22.08868980407715, -23.040000915527344, -26.257713317871094, -20.63900375366211, -23.392274856567383, -22.723669052124023, 12.80344295501709, -24.490678787231445, -29.74073028564453, 64.12638854980469, -24.47040367126465, -25.418689727783203, -24.032339096069336, -20.691490173339844, -22.222122192382812, -53.712425231933594, 14.840564727783203, -28.15567398071289, -23.059268951416016, -26.850736618041992, -25.2841854095459, -22.090087890625, 14.943015098571777, -24.196142196655273, -25.44603157043457, -17.415332794189453, -23.85368537902832, -29.819902420043945, -24.374998092651367, -19.174741744995117, -24.03484535217285, -18.598222732543945, -19.097970962524414, -24.130203247070312, -24.821325302124023, 12.542951583862305, -30.812694549560547, 2.4757981300354004, -24.866151809692383, -20.331066131591797, -27.041248321533203, -25.021604537963867, -23.417484283447266, -24.902402877807617, -23.791147232055664, 44.071022033691406, -14.601216316223145, -22.528913497924805, -25.3341121673584, -25.553619384765625, 42.209327697753906, -26.01548194885254, 8.590210914611816, 15.799221992492676, 14.070558547973633, -23.956575393676758, -28.637033462524414, -28.399272918701172, -26.240381240844727, 15.686745643615723, -24.84347915649414, -24.978160858154297, -20.140316009521484, -26.756263732910156, 15.606009483337402, -20.850929260253906, -24.083637237548828, 13.467188835144043, -24.66598129272461, 2.4195239543914795, 12.951187133789062, -21.67452621459961, 16.791566848754883, -18.619050979614258, -19.863487243652344, 17.42499351501465, -25.955984115600586, -26.852394104003906, -35.01143264770508, -19.986543655395508, -25.746387481689453, 15.595458030700684, -21.563814163208008, -20.567604064941406, 16.23795509338379, -25.900474548339844, 13.641693115234375, -24.191085815429688, 8.127094268798828, -28.546335220336914, -34.42100524902344, 13.189057350158691, 13.923044204711914, 8.259969711303711, -28.318403244018555, -28.085887908935547, -28.214494705200195, -28.18278694152832, -28.7767333984375, -27.754295349121094, 13.840423583984375, 30.598613739013672, 31.083663940429688, -27.26368522644043, 2.1340668201446533, -14.27587604522705, -28.55572509765625, -26.86684226989746, 14.669617652893066, 3.9460318088531494, 10.92241096496582, -34.226810455322266, 61.14817810058594, -21.76727867126465, -26.409297943115234, 60.84351348876953, 13.03765869140625, -39.54838180541992, -27.290870666503906, -28.043638229370117, -27.969215393066406, -21.634714126586914, -27.333650588989258, -22.879898071289062, 59.850852966308594, -21.036684036254883, -21.41654396057129, -27.941762924194336, -27.361204147338867, -24.316495895385742, 16.92891502380371, -22.331771850585938, -24.5811824798584, -23.120845794677734, 13.839954376220703, -19.981199264526367, 61.678348541259766, 30.57564353942871, -28.627315521240234, 66.23 ...

# %%
knn(dfCic)
# Out:
# [[246   8]
#  [ 75 213]]
#               precision    recall  f1-score   support
#
#           -1       0.77      0.97      0.86       254
#            1       0.96      0.74      0.84       288
#
#    micro avg       0.85      0.85      0.85       542
#    macro avg       0.87      0.85      0.85       542
# weighted avg       0.87      0.85      0.85       542
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# # Eng

# %%
PCA(dfEng)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfEng)
# Out:
# <div id="8383c266-69f6-40e5-af44-99b58fbfd478" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("8383c266-69f6-40e5-af44-99b58fbfd478")) {
#     Plotly.newPlot("8383c266-69f6-40e5-af44-99b58fbfd478", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "0", "x": [-16.11280059814453, 13.582627296447754, -7.2854790687561035, 12.64030933380127, -3.8538994789123535, 20.76555824279785, -4.830300331115723, 13.586226463317871, 7.277968406677246, -16.7679443359375, 7.150597095489502, 7.273978233337402, -4.694134712219238, 9.177104949951172, 8.797887802124023, 8.417048454284668, 20.469364166259766, -17.93069076538086, 13.156041145324707, 22.12052345275879, -6.43718147277832, 11.407475471496582, 2.4428634643554688, -4.925919055938721, 15.650435447692871, 10.902349472045898, -5.930049896240234, 20.92715835571289, 14.648397445678711, 8.577573776245117, 19.751972198486328, -5.534298896789551, -1.2912635803222656, 15.439943313598633, 4.908774375915527, 10.817203521728516, -5.296759128570557, 20.018993377685547, 9.493505477905273, -4.482726097106934, 19.089731216430664, 17.392257690429688, 9.678753852844238, 4.200725555419922, -15.7810697555542, 19.339059829711914, 14.14309310913086, 23.38129425048828, 10.900343894958496, 21.05642318725586, 8.375343322753906, -5.579924583435059, 23.06043815612793, -8.086273193359375, 13.544415473937988, 11.72057056427002, 6.890726089477539, 15.046448707580566, -7.756049633026123, 5.171478271484375, 7.139634609222412, 9.633150100708008, 21.32243537902832, -3.337505578994751, 8.809502601623535, -16.665630340576172, 16.2299861907959, 4.642045497894287, 2.5492217540740967, -2.623990535736084, 7.15688943862915, 18.385988235473633, 20.804487228393555, 8.694108963012695, -7.527819633483887, -6.097163677215576, 6.639133930206299, -7.2984185218811035, -20.952119827270508, -5.80396032333374, 9.017501831054688, 23.059240341186523, 16.597564697265625, 17.020587921142578, 9.259912490844727, 9.814579963684082, 23.211774826049805, -13.62181282043457, 5.705677032470703, 9.806844711303711, 18.10906982421875, -3.340261459350586, 16.196958541870117, 16.126327514648438, 22.848472595214844, 2.0096275806427, 18.02018165588379, 21.932065963745117, -13.555171966552734, 10.386402130126953, 14.583815574645996, -14.392663955688477, 5.263980865478516, -6.5937652587890625, 8.422616004943848, 13.60197639465332, 8.63746166229248, 6.51882791519165, -9.122880935668945, 7.479185104370117, 8.442873001098633, 4.600518703460693, 7.51402473449707, 16.073270797729492, 23.905393600463867, -8.26653003692627, 10.346170425415039, 1.2745949029922485, -6.344698905944824, 18.269407272338867, 9.091054916381836, 23.4851131439209, 24.13572120666504, 5.613182544708252, 5.801210880279541, 7.265286922454834, 6.3418073654174805, 9.068379402160645, 11.717628479003906, 6.622314929962158, 7.469399929046631, 8.102363586425781, -19.86168670654297, 7.142459869384766, 24.546478271484375, 10.164046287536621, 10.30767822265625, 4.781060218811035, 11.27153205871582, 22.562870025634766, 14.265575408935547, 16.752384185791016, 6.841980457305908, 7.543485164642334, 12.079463958740234, 19.99305534362793, 21.166934967041016, 22.389759063720703, 11.380255699157715, 11.43956184387207, 13.2478666305542, 11.980123519897461, 14.414137840270996, 19.098207473754883, 15.181963920593262, 6.917867183685303, 21.08098030090332, 14.664345741271973, 22.031368255615234, 4.265697479248047, -2.412755012512207, -16.03876495361328, 19.0704288482666, 24.028989791870117, 6.203503131866455, 8.72624683380127, 1.9420119524002075, 10.728172302246094, 9.9884614944458, 9.165339469909668, 5.629770755767822, 9.080069541931152, 6.0264458656311035, 6.707736015319824, 6.967983722686768, 21.917829513549805, 6.566473007202148, 11.866674423217773, 8.824463844299316, 23.145275115966797, 22.120573043823242, 7.376348972320557, 7.123256683349609, -18.71957778930664, 5.435269355773926, -4.339372634887695, 7.225635528564453, 8.456231117248535, 5.02679967880249, 4.542541980743408, 9.93201732635498, 9.624068260192871, 21.619678497314453, 5.756546497344971, 4.973392963409424, 6.86544942855835, 7.263776779174805, 7.20 ...

# %%
knn(dfEng)
# Out:
# [[23  2]
#  [ 6 41]]
#               precision    recall  f1-score   support
#
#           -1       0.79      0.92      0.85        25
#            1       0.95      0.87      0.91        47
#
#    micro avg       0.89      0.89      0.89        72
#    macro avg       0.87      0.90      0.88        72
# weighted avg       0.90      0.89      0.89        72
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
