# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.manifold import TSNE

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# df = pd.read_csv("teste.csv", index_col=0)

# %%
# df[df['ID Aluno']==208149] #id

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.offline as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # preparing data

# %%
primeiroCiC = ['116301', '118001', '118010', '113034', '140481', '145971']
segundoCiC = ['116319', '115045', '118028', '118036', '113042']
terceiroCiC = ['118044', '118052', '113956', '113051', '117366']


primeiroLic1 =['116793', '117366', '145971', '147389', '194221']
segundoLic1 = ['113034', '116301', '125156']
terceiroLic1 = ['115045', '116319', '125172']

primeiroLic2 =['113492', '194221', '113450', '113476']
segundoLic2 = ['113034', '116319', '191027', '150649', '194280']
terceiroLic2 = ['115045', '113093', '117366', '117889']

primeiroEngComp =['113034', '113093', '113476', '117528', '118001', '118010']
segundoEngComp = ['118028', '118036', '113042', '115045', '116319']
terceiroEngComp =['113051', '117242', '170054', '201600', '206075']


primeiroMec = ['114626', '114634', '118010', '113476', '113034', '118001', '168891']
segundoMec = ['168891', '113093', '118028', '118036', '115045', '168874']
terceiroMec = ['113051', '118044', '118052', '168769', '116319']

primeiroRedes = ['113034', '113093', '118001', '118010', '167959']
segundoRedes = ['113042', '115045', '118028', '118036', '169676']
terceiroRedes = ['113051', '113301', '167983', '169749']


undropableCol = ["curso","saiu","Cotista","Raça","Sexo","Tipo de Escola"]#, 'Ingresso_unb'

# %%
df0 = pd.read_csv("aluno_quant_Materias_Media_cotistas_0.csv", index_col=0)
df1 = pd.read_csv("aluno_quant_Materias_Media_cotistas_1.csv", index_col=0)
df2 = pd.read_csv("aluno_quant_Materias_Media_cotistas_2.csv", index_col=0)
df3 = pd.read_csv("aluno_quant_Materias_Media_cotistas_3.csv", index_col=0)
df4 = pd.read_csv("aluno_quant_Materias_Media_cotistas_4.csv", index_col=0)
df5 = pd.read_csv("aluno_quant_Materias_Media_cotistas_5.csv", index_col=0)

# %%
dfComp = df0[undropableCol+primeiroLic1+segundoLic1+terceiroLic1].fillna(-1)
dfRedes = df1[undropableCol+primeiroRedes+segundoRedes+terceiroRedes].fillna(-1)
dfCic = df2[undropableCol+primeiroCiC+segundoCiC+terceiroCiC].fillna(-1) 
dfMec = df3[undropableCol+primeiroMec+segundoMec+terceiroMec].fillna(-1) 
dfEng = df4[undropableCol+primeiroEngComp+segundoEngComp+terceiroEngComp].fillna(-1)

# %% [markdown]
# # PCA

# %%
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)

# %%
def PCA (df, currentLabel = 'saiu'):
    data = (
        df

    )
    
    x = data.iloc[:].values
    y = data[currentLabel].values

    data[currentLabel]
    numColors = len(data[currentLabel].unique())

    sklearn_pca = sklearnPCA(n_components=2)

    Y_sklearn = sklearn_pca.fit_transform(x)

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    with plt.style.context('seaborn-whitegrid'):
        plt.figure(figsize=(15, 10))
        for lab, col in zip(data[currentLabel].unique(),
                            colorList):
            plt.scatter(Y_sklearn[y==lab, 0],
                        Y_sklearn[y==lab, 1],
                        label=lab,
                        c=col)
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend(loc='lower right')
        plt.tight_layout()
        plt.show()

    plt.show()

# %% [markdown]
# # TSNE

# %%
def formatColor(color):
    return 'rgb('+str(int(color[0]*255))+','+str(int(color[1]*255))+','+str(int(color[2]*255))+')'

    
def tsne(df, currentLabel = 'saiu'):
    a = df
    X = a.values
    X_embedded = TSNE(n_components=2).fit_transform(X)
    
    
    data = a
    Y_sklearn = X_embedded
    y = data[currentLabel].values
    numColors = len(data[currentLabel].unique())

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    traceArr = []
    for lab, col in zip(data[currentLabel].unique(),
                        colorList):
        
        trace1 = go.Scatter(
            x=Y_sklearn[y==lab, 0],
            y=Y_sklearn[y==lab, 1],
#             z=Y_sklearn[y==lab, 2],
            mode='markers',
            name = str(lab),
            marker=dict(
                size=5,
                color=formatColor(col),
                opacity=0.8
            )
        )
        traceArr.append(trace1)

    data = traceArr
    layout = go.Layout(
        margin=dict(
            l=0,
            r=0,
            b=0,
            t=0
        )
    )
    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, filename='3d-scatter-colorscale')

# %%
# draw2dFrame(a, X_embedded, 'saiu')

# %% [markdown]
# # knn

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# a = a[a["saiu"]!=0]
# y = a["saiu"]
# X = a.drop(["saiu"], axis = 1)

# %%
def knn (df, currentLabel = 'saiu'):
    a = df[df[currentLabel]!=0]
    y = a[currentLabel]
    X = a.drop([currentLabel], axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35)
    scaler = StandardScaler()  
    scaler.fit(X_train)

    X_train = scaler.transform(X_train)  
    X_test = scaler.transform(X_test)  
    
    classifier = KNeighborsClassifier(n_neighbors=2)  
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    
    print(confusion_matrix(y_test, y_pred))  
    print(classification_report(y_test, y_pred))

# %%
# scaler = StandardScaler()  
# scaler.fit(X_train)

# X_train = scaler.transform(X_train)  
# X_test = scaler.transform(X_test)

# %%
# classifier = KNeighborsClassifier(n_neighbors=2)  
# classifier.fit(X_train, y_train)
# y_pred = classifier.predict(X_test)

# %%
 
# print(confusion_matrix(y_test, y_pred))  
# print(classification_report(y_test, y_pred))
# knn(X, y)

# %%
# a

# %% [markdown]
# ## Comp

# %%
PCA(dfComp)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfComp)
# Out:
# <div id="93953d02-060a-489e-8292-250f00d4963f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("93953d02-060a-489e-8292-250f00d4963f")) {
#     Plotly.newPlot("93953d02-060a-489e-8292-250f00d4963f", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [-5.890942096710205, -9.42250919342041, 4.491769790649414, 13.247001647949219, 1.6917078495025635, -5.440357208251953, 5.926297664642334, -4.65177059173584, -5.240692615509033, -1.7776967287063599, 5.755419731140137, 5.572513103485107, 6.8472208976745605, 5.076077938079834, 1.8515808582305908, 5.306212425231934, 8.20076847076416, 3.869279384613037, 5.710784435272217, 6.807396411895752, -2.7723681926727295, 9.312090873718262, 4.795934677124023, 7.99136209487915, -5.366379737854004, 3.4189937114715576, -8.901416778564453, 7.158792495727539, -5.001072406768799, -5.389599323272705, -4.4348464012146, -4.6164655685424805, 7.513956546783447, -7.4404497146606445, -5.3394455909729, 2.071241855621338, 0.1352684199810028, 0.24106137454509735, 7.14003849029541, -7.18118143081665, 0.8562973737716675, 9.680167198181152, 3.1390135288238525, -3.375901699066162, 0.8088815808296204, 7.537485122680664, -5.570587635040283, -4.8560471534729, 7.521581172943115, 7.526905536651611, 4.890292167663574, 10.314010620117188, 7.188342571258545, 6.713554859161377, -2.6972594261169434, 4.581638336181641, -4.9053955078125, 0.8027687668800354, 7.135758399963379, 5.926979064941406, 9.569853782653809, 7.416600704193115, 4.637849807739258, 5.846877574920654, 5.793779373168945, 4.002038478851318, 10.040491104125977, 7.096017360687256, -5.8822245597839355, -5.741714000701904, -3.478358268737793, 0.6310319900512695, -5.401414394378662, 8.969518661499023, -3.9115374088287354, 5.166790962219238, 6.640215873718262, -6.675848484039307, 5.682005882263184, 7.041103363037109, 1.6610510349273682, 5.889792442321777, 1.4820692539215088, -6.597433090209961, -7.467855453491211, 5.359977722167969, -4.7572855949401855, -5.426758766174316, 8.729732513427734, -2.793423891067505, -6.316512584686279, -6.314870834350586, -6.316512584686279, -6.715165615081787, -6.717050552368164], "y": [-5.719055652618408, -7.560704708099365, 9.397313117980957, 9.602688789367676, -0.5615113377571106, -4.440674304962158, 10.707762718200684, -3.835564613342285, -3.9059581756591797, 2.1851260662078857, 9.437418937683105, 9.1106595993042, 5.80355978012085, 9.67996597290039, 0.5365917682647705, 2.3698062896728516, 11.960912704467773, 7.020827770233154, 8.351202964782715, 2.581467866897583, 0.8086941242218018, 11.778114318847656, 7.476042747497559, 13.747076988220215, -4.991398334503174, -0.15255999565124512, -5.901424884796143, 9.484153747558594, -6.818946838378906, -4.979032516479492, -5.45418643951416, -4.137566089630127, 4.66126823425293, 2.414451837539673, -5.005744934082031, -0.8411575555801392, 1.6379774808883667, 2.915099859237671, 6.650101184844971, -6.811924457550049, 3.029606342315674, 6.787018299102783, -0.35344183444976807, 1.735172152519226, 2.8879892826080322, 2.763049602508545, -5.895498752593994, -1.6378793716430664, 2.603640079498291, 2.1916542053222656, 4.951595783233643, 5.545102119445801, 2.0136563777923584, 1.8308169841766357, 0.2673335373401642, 7.316822528839111, -2.857116460800171, 4.336658477783203, 4.302282810211182, 2.9209046363830566, 5.991789817810059, 3.6945269107818604, 1.4754847288131714, 1.8447415828704834, 1.946173071861267, 2.684652328491211, 4.123013496398926, 0.8246088027954102, -3.14496111869812, -1.020323395729065, 1.741697072982788, 3.260181427001953, -3.11706805229187, 4.633410453796387, -3.648597002029419, 4.705927848815918, 1.0614488124847412, -1.8744721412658691, 3.1848864555358887, 0.4492988586425781, -0.45442110300064087, 2.564915657043457, -0.4445508122444153, -1.9706875085830688, 2.413127899169922, 1.5652165412902832, -3.3706436157226562, -1.6781766414642334, 0.36867859959602356, -0.014418155886232853, -4.167548179626465, -4.164018154144287, -4.167548179626465, -3.46919322013855, -3.470521926879883], "type": "scatter", "uid": "81122b34-33da-4a29-b971-2350312b1e35"}, {"marker": {"color": "rgb(0,15,255 ...
# }
# })

# %%
knn(dfComp)
# Out:
# [[10  0]
#  [ 7 27]]
#               precision    recall  f1-score   support
#
#           -1       0.59      1.00      0.74        10
#            1       1.00      0.79      0.89        34
#
#    micro avg       0.84      0.84      0.84        44
#    macro avg       0.79      0.90      0.81        44
# weighted avg       0.91      0.84      0.85        44
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ## Redes

# %%
PCA(dfRedes)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfRedes)
# Out:
# <div id="aa9887b0-de3f-49c4-a241-5aa21b7e2e24" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("aa9887b0-de3f-49c4-a241-5aa21b7e2e24")) {
#     Plotly.newPlot("aa9887b0-de3f-49c4-a241-5aa21b7e2e24", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [-15.731125831604004, -14.142234802246094, -14.843484878540039, -14.227166175842285, -14.649179458618164, -14.336468696594238, -14.105846405029297, 5.18456506729126, -16.34554100036621, -15.450108528137207, -16.894742965698242, -15.95854663848877, -16.079797744750977, 3.3036694526672363, -14.732717514038086, -11.750755310058594, -16.68475914001465, -13.943235397338867, -15.284111022949219, -16.83970069885254, -15.563312530517578, 3.3281500339508057, 3.4023280143737793, 7.6855788230896, -14.833003997802734, -13.898526191711426, -13.535895347595215, 9.92523193359375, -14.605453491210938, -15.197080612182617, -15.553533554077148, -14.443466186523438, -15.259438514709473, -14.621912002563477, 3.487295150756836, 6.795415878295898], "y": [7.063370227813721, 8.643000602722168, 8.454366683959961, 8.613110542297363, 9.638041496276855, 9.06723690032959, 9.470365524291992, -5.236319065093994, 9.469218254089355, 10.716294288635254, 11.128564834594727, 8.350738525390625, 8.638481140136719, -9.328646659851074, 8.543704986572266, 7.675655841827393, 8.416853904724121, 9.546316146850586, 11.215302467346191, 9.12989330291748, 6.346116065979004, -9.255685806274414, -9.038604736328125, -3.2834670543670654, 6.841930389404297, 8.393447875976562, 9.062433242797852, -5.372955322265625, 7.849802017211914, 8.161771774291992, 9.195602416992188, 6.508913040161133, 9.274913787841797, 7.738347053527832, -8.811447143554688, -2.025585889816284], "type": "scatter", "uid": "afafc1d6-bd3b-4b87-b254-c30ab2e95d08"}, {"marker": {"color": "rgb(0,15,255)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [-12.327588081359863, -14.938952445983887, -12.932144165039062, -13.110979080200195, -1.3673582077026367, -13.445013999938965, -0.08483962714672089, -13.864684104919434, -13.608187675476074, -13.899227142333984, -12.837312698364258, 1.6588910818099976, -1.6655784845352173, -10.145447731018066, 3.0614845752716064, 1.0151731967926025, 1.282873272895813, 6.599154472351074, -9.504568099975586, 4.1536993980407715, -10.658639907836914, -3.776319980621338, 6.059428691864014, 8.421908378601074, 4.780564308166504, -0.35803940892219543, 0.6320001482963562, 8.38523006439209, 6.562960624694824, 4.815330505371094, 9.119536399841309, -0.11193783581256866, 6.599196434020996, 4.216503143310547, 8.798612594604492, 6.456603527069092, 0.9920699596405029, -3.4503514766693115, 9.07450008392334, 1.5256587266921997, -0.7004748582839966, -3.143123149871826, 5.6055169105529785, 4.519753932952881, 4.853439807891846, 4.606956958770752, -4.60172700881958, 5.100485324859619, 0.919241726398468, 7.471617221832275, 0.5800615549087524, 5.0688300132751465, 5.256804943084717, -2.9585518836975098, 1.263677954673767, 2.258983850479126, 2.8378939628601074, -9.261348724365234, -2.069334030151367, -0.8647218346595764, 2.2135345935821533, 1.9417444467544556, 1.9723066091537476, 3.69443416595459, 2.1840922832489014, -0.3685528039932251, 6.599196910858154, -1.2420390844345093, 0.728269100189209, 6.205772399902344], "y": [8.640853881835938, 11.179214477539062, 8.787513732910156, 7.835416793823242, -2.202183485031128, 7.7670769691467285, -1.8740084171295166, 6.798550605773926, 10.439231872558594, 7.32087516784668, 9.352084159851074, -2.2106590270996094, -0.8059464693069458, 7.965863227844238, -2.4152615070343018, 0.2366257607936859, 0.5602254271507263, -3.457697868347168, 1.125182867050171, -1.0243502855300903, 7.52987003326416, 1.9232572317123413, -3.912071943283081, -4.219557285308838, -3.5526843070983887, 0.16159947216510773, 1.4276829957962036, -5.048041343688965, -3.4437670707702637, -2.9426162242889404, -4.282945156097412, -1.5242372751235962, -3.4576897621154785, -2.726803779602051, -3.177180528640747, -4.092386245727539, -1.737421989440918, 2.0519378185272217, -2.6935276985168457, -1.2291558980941772, -1.5269513130187988, 1.07 ...
# }
# });</script><script type="text/javascript">window.addE

# %%
knn(dfRedes)
# Out:
# [[13  0]
#  [ 7 18]]
#               precision    recall  f1-score   support
#
#           -1       0.65      1.00      0.79        13
#            1       1.00      0.72      0.84        25
#
#    micro avg       0.82      0.82      0.82        38
#    macro avg       0.82      0.86      0.81        38
# weighted avg       0.88      0.82      0.82        38
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ## Mec

# %%
PCA(dfMec)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfMec)
# Out:
# <div id="6428c502-deae-4874-bda6-4f6f0b3c6d88" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("6428c502-deae-4874-bda6-4f6f0b3c6d88")) {
#     Plotly.newPlot("6428c502-deae-4874-bda6-4f6f0b3c6d88", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [9.559168815612793, 9.223121643066406, 9.98659896850586, 10.10302734375, 10.053362846374512, 10.188132286071777, 11.267943382263184, 10.039657592773438, 10.617544174194336, 11.063075065612793, -0.4158383905887604, 12.485925674438477, 11.879593849182129, 13.586197853088379, 11.573728561401367, 14.517621994018555, 11.652847290039062, 13.9859037399292, 13.084944725036621, 11.812466621398926], "y": [-13.010319709777832, -13.709163665771484, -13.418013572692871, -13.378242492675781, -13.566728591918945, -13.8579740524292, -13.704826354980469, -14.089461326599121, -6.6817450523376465, -13.375483512878418, 0.297277569770813, -5.699891567230225, -5.935235023498535, -6.001260280609131, -6.819980621337891, -7.971737861633301, -8.76278305053711, -5.673282146453857, -7.545937538146973, -5.185002326965332], "type": "scatter", "uid": "8c67c7e4-8a75-432e-94fb-9c330f612e46"}, {"marker": {"color": "rgb(0,15,255)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [-8.263998985290527, 10.20782470703125, 9.527871131896973, -13.143062591552734, 10.115540504455566, -6.287109851837158, -9.49914836883545, -2.6744296550750732, -6.573996067047119, 9.00877857208252, 9.845276832580566, 8.64575481414795, -13.756340980529785, 9.08729362487793, 3.85945463180542, 8.015206336975098, -8.163909912109375, -0.9992586970329285, -7.852780818939209, -13.104558944702148, 3.534999132156372, 3.9915921688079834, 2.1008596420288086, 8.058772087097168, 8.042778968811035, -1.4100104570388794, -6.451027870178223, -0.8213713765144348, -12.355939865112305, 9.757796287536621, -7.12768030166626, 9.986276626586914, 7.03391695022583, 3.263159990310669, -7.242606163024902, -1.0414334535598755, 6.816787242889404, -8.69140625, -7.143439769744873, -8.101099014282227, -9.780815124511719, 6.964542865753174, 1.9985712766647339, 10.064764022827148, -13.032675743103027, 8.870985984802246, 4.503003120422363, -1.7926580905914307, -1.8663146495819092, -13.829381942749023, -14.002035140991211, -7.449497222900391, -6.958685398101807, -2.0216617584228516, -12.309178352355957, -12.268477439880371, 0.7690657377243042, -2.88149356842041, -5.835432052612305, -7.498403549194336, -4.277708530426025, 0.6204818487167358, -12.101393699645996, -11.41773509979248, -13.02054214477539, -4.908110618591309, -13.379607200622559, -0.9465663433074951], "y": [5.132588863372803, -12.618595123291016, -12.846582412719727, 11.177210807800293, -14.46323299407959, 7.859407424926758, 8.135897636413574, 6.795039653778076, 8.451303482055664, -8.954224586486816, -7.29567813873291, -7.2773518562316895, 7.090564727783203, -7.885411739349365, -0.7097737193107605, -9.56247329711914, 5.077420234680176, 0.13102108240127563, 7.3616743087768555, 8.590730667114258, -1.6998666524887085, -1.31183660030365, -1.981524109840393, -9.803961753845215, -7.991412162780762, 3.6130642890930176, 8.969978332519531, 3.6709060668945312, 8.758971214294434, -5.899441719055176, 9.076433181762695, -5.915930271148682, -6.345090389251709, -6.998091697692871, 8.307233810424805, 3.767791509628296, -7.284066200256348, 6.700566291809082, 8.58148193359375, 6.676480293273926, 7.669802188873291, -6.626019477844238, 0.6925280690193176, -6.627752304077148, 7.386711120605469, -6.887078762054443, -0.79976487159729, 4.184516906738281, 2.005479335784912, 8.951420783996582, 7.400025367736816, 6.266271591186523, 5.851434230804443, 3.9376578330993652, 10.646439552307129, 9.282641410827637, 1.5031230449676514, 3.185157060623169, 4.514697074890137, 7.081691265106201, 6.767788887023926, 1.6465516090393066, 9.680495262145996, 9.560565948486328, 8.794029235839844, 2.84409499168396, 9.709587097167969, 4.670372486114502], "type": "scatter", "uid": "25036671-e581-4f1f-910a-cdd5a853ba14"}, {"marker": {"color": "rgb(255,0,23)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "0", "x": [10.2991361 ...

# %%
knn(dfMec)
# Out:
# [[ 8  3]
#  [ 2 18]]
#               precision    recall  f1-score   support
#
#           -1       0.80      0.73      0.76        11
#            1       0.86      0.90      0.88        20
#
#    micro avg       0.84      0.84      0.84        31
#    macro avg       0.83      0.81      0.82        31
# weighted avg       0.84      0.84      0.84        31
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# # CIC

# %%
PCA(dfCic)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfCic)
# Out:
# <div id="62096f47-e096-47a1-a1e3-42589a8e3e43" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("62096f47-e096-47a1-a1e3-42589a8e3e43")) {
#     Plotly.newPlot("62096f47-e096-47a1-a1e3-42589a8e3e43", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [-2.9068307876586914, 1.9593108892440796, 0.9457216262817383, 8.833290100097656, 8.582314491271973, 9.399060249328613, 6.692546367645264, 5.969687461853027, -10.981664657592773, 0.6304129362106323, 2.631481885910034, 12.141016960144043, 5.020519733428955, 7.7085371017456055, -4.210336685180664, -8.283143043518066, -4.8450422286987305, 8.63282299041748, -8.410690307617188, -5.971337795257568, 7.725492477416992, -5.132422924041748, -0.4132857322692871, -1.1722413301467896, 6.03792142868042, -8.697408676147461, -1.2011653184890747, -1.8656635284423828, -1.8980774879455566, 11.526599884033203, -10.177018165588379, -2.139902353286743, 2.7876296043395996, 9.938501358032227, -1.794540524482727, 0.3291456997394562, -6.917511940002441, -3.858302116394043, 0.6441179513931274, 6.282066822052002, -1.4079560041427612, -10.969019889831543, -4.258813381195068, -2.3693811893463135, -1.0254757404327393, 1.9014506340026855, 0.014430543407797813, -4.832308292388916, 0.605316698551178, -1.3172500133514404, -0.26861852407455444, -1.1679548025131226, -11.507081985473633, -4.481974124908447, -0.8628617525100708, -0.31599611043930054, -5.165026664733887, 1.5268059968948364, -2.7405855655670166, -4.6924004554748535, -3.204845428466797, -0.9971089959144592, -1.6515510082244873, -7.238868236541748, -5.77023458480835, -2.2411677837371826, -4.73726749420166, -2.9579172134399414, -1.1668918132781982, -1.692961573600769, 0.15480852127075195, -4.519791126251221, -1.8520476818084717, -5.920362949371338, 1.0820715427398682, 7.688083648681641, -5.421390533447266, -0.8224207162857056, -6.0745439529418945, -9.482529640197754, -8.675721168518066, -6.857529640197754, -7.428976535797119, -7.278127670288086, -6.772911548614502], "y": [2.6966776847839355, -1.5853607654571533, -2.9292266368865967, -8.3916015625, -10.967241287231445, -10.338410377502441, -6.513957977294922, -5.977845191955566, 3.913496732711792, -0.5702952742576599, -0.39858028292655945, -9.626218795776367, -3.8990373611450195, -6.331295013427734, 4.219515800476074, 4.790363788604736, 1.1096373796463013, -11.182252883911133, 10.761993408203125, -0.058864910155534744, -12.94495964050293, 6.7268805503845215, -4.809703350067139, -1.378090262413025, -8.834595680236816, 4.071506500244141, -2.4320054054260254, -2.0437495708465576, -2.9855659008026123, -10.463935852050781, 6.30855131149292, -1.62803316116333, -5.693997859954834, -10.966164588928223, -2.4320061206817627, -4.217696189880371, 3.7733821868896484, 1.7405871152877808, -4.5396952629089355, -8.796272277832031, -3.3881099224090576, 10.958711624145508, 4.179983139038086, -1.0218877792358398, -3.409628391265869, -3.9304864406585693, -3.922492504119873, 0.1965676248073578, -3.804765462875366, -2.1852071285247803, -3.3588263988494873, -1.2304034233093262, 8.731724739074707, -0.13389025628566742, -4.528791427612305, -5.467348575592041, 2.8507466316223145, -3.682955265045166, -1.4616749286651611, 3.197298526763916, 2.4223148822784424, -1.019845724105835, -1.0618988275527954, 3.5982632637023926, 3.928025007247925, -2.523648977279663, 3.324145555496216, -2.8459115028381348, -4.783411026000977, -1.465768814086914, -1.9492316246032715, 0.8568167090415955, -1.569165825843811, 4.146709442138672, -3.2016334533691406, -6.475208759307861, 3.5555522441864014, -1.8579152822494507, 4.93541145324707, 8.762395858764648, 5.097590923309326, 6.489383220672607, 7.822719097137451, 5.545408725738525, 7.4012956619262695], "type": "scatter", "uid": "68441547-71ef-4d7c-b3ab-1448d2e86cab"}, {"marker": {"color": "rgb(0,15,255)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [-4.4277496337890625, 2.892338275909424, 11.982077598571777, 12.014941215515137, 11.772705078125, 11.473856925964355, 11.412128448486328, 12.909479141235352, 11.524063110351562, 12.724690437316895, 11.794921875, 12.195358276367188, 11 ...

# %%
knn(dfCic)
# Out:
# [[10  1]
#  [ 2 27]]
#               precision    recall  f1-score   support
#
#           -1       0.83      0.91      0.87        11
#            1       0.96      0.93      0.95        29
#
#    micro avg       0.93      0.93      0.93        40
#    macro avg       0.90      0.92      0.91        40
# weighted avg       0.93      0.93      0.93        40
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# # Eng

# %%
PCA(dfEng)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfEng)
# Out:
# <div id="e1cb763e-e3c7-4450-a85a-e74c68589153" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("e1cb763e-e3c7-4450-a85a-e74c68589153")) {
#     Plotly.newPlot("e1cb763e-e3c7-4450-a85a-e74c68589153", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [9.250775337219238, -6.854677677154541, 6.597469806671143, -9.189528465270996, -8.128246307373047, 0.2957789897918701, -6.9539384841918945, -7.198293685913086, -9.009764671325684, 6.582686901092529, 7.1240234375, 5.258667945861816, -9.107098579406738, 0.3953414261341095, 6.382965564727783, 11.067828178405762, 5.626274585723877, -2.1521408557891846, -1.8963812589645386, -0.5420189499855042, -7.649275779724121, 5.747461318969727, -1.6354111433029175, -0.29790085554122925, 8.187851905822754, 7.774998664855957, 7.23996639251709, 8.313249588012695, 6.353639602661133, 5.619504928588867, -2.3746795654296875, 4.8683366775512695, 0.2705844044685364, 7.8474440574646, 5.287320137023926, 6.144162654876709, 8.945817947387695, 6.205145359039307, 7.315533638000488, 6.134247303009033, 6.403364658355713, 6.671602725982666, 6.473255634307861, 7.469623565673828, -6.818426609039307, -0.7891020178794861, -3.9040613174438477, 7.59783411026001, -2.77882719039917, -2.469954013824463, -1.2339000701904297, 8.394119262695312, 6.679962158203125, 7.32172155380249, 5.296389579772949, -0.91243577003479, 0.9942646026611328, 6.507833957672119, -0.03274025022983551, 4.158038139343262, 3.4959726333618164, 6.856724262237549, 2.8717854022979736, 7.280685901641846, 6.501402378082275, -5.166494369506836, 7.133294105529785, 4.295412540435791, 7.315640926361084, 4.608202934265137], "y": [4.694966793060303, -4.783270835876465, 0.8873034715652466, -9.579103469848633, -8.430212020874023, 6.508303165435791, -4.055067539215088, -7.77509880065918, -9.502394676208496, 9.077205657958984, 6.400954723358154, 6.499597072601318, -7.857433319091797, 6.485480308532715, 3.1281466484069824, 6.411885738372803, 4.796733856201172, -5.841451644897461, 2.7294650077819824, -6.0272932052612305, -7.582361698150635, 3.3112387657165527, -6.280832290649414, -6.115681171417236, 2.00193452835083, 1.6204581260681152, 1.8747471570968628, 1.796879768371582, 7.543668270111084, 4.8785481452941895, 2.135908603668213, 5.0357842445373535, -6.032677173614502, 7.757840633392334, 4.263611316680908, 1.705348253250122, 6.5248823165893555, 2.0929057598114014, 8.492416381835938, 5.627013683319092, 3.852543592453003, 6.920095443725586, 8.815323829650879, 3.0373036861419678, -7.796154499053955, -5.891816139221191, -2.7987406253814697, 5.875209331512451, 0.20302174985408783, -1.3799725770950317, 1.4674584865570068, 7.667836666107178, 7.165804386138916, 7.604927062988281, -0.3052850663661957, 1.261631965637207, -2.188687324523926, 1.8146626949310303, -2.469954490661621, -1.809264898300171, 2.4066779613494873, 8.249811172485352, 3.3778884410858154, 4.479296684265137, 10.473661422729492, -3.96791934967041, 7.953495502471924, 6.9108991622924805, 8.492520332336426, 0.6192116737365723], "type": "scatter", "uid": "78e0cdfe-fe4f-4608-87d8-bce3bc7f9925"}, {"marker": {"color": "rgb(0,15,255)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "0", "x": [-9.311267852783203, -9.583845138549805, -9.887380599975586, -8.149066925048828, -8.39055347442627, -9.550119400024414, -9.191060066223145, -9.794097900390625, 9.999839782714844, -7.288176536560059, 7.977609157562256, -9.53328800201416, -1.969543218612671, -10.460010528564453, -1.2168620824813843, -10.954390525817871, -6.364943504333496, -7.501245021820068, -10.650616645812988, -7.2539873123168945, -9.752846717834473, -3.070852041244507, -2.3231921195983887, -8.801660537719727, -2.7468504905700684, -7.0597615242004395, -0.7976971864700317, -8.22464370727539, -7.621158599853516, -4.782783508300781, -1.2102715969085693, -5.130575180053711, -0.8555845022201538, -6.213615894317627, 4.6903886795043945, -5.1787333488464355, -4.957493782043457, -4.6617817878723145, 3.2477951049804688, 2.157247543334961, -4.614111423492432, -1.2917063236236572, 3.7354788780212402, 4.2098283767700195, -4.730992794036865, 3.0321090221405 ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("e1cb763e-e3c7-4450-a85a-e74c68589153")) {window._Plotly.Plots.resize(document.getElementById("e1cb763e-e3c7-4450-a85a-e74c68589153"));};})</script>

# %%
knn(dfEng)
# Out:
# [[ 2  1]
#  [ 0 24]]
#               precision    recall  f1-score   support
#
#           -1       1.00      0.67      0.80         3
#            1       0.96      1.00      0.98        24
#
#    micro avg       0.96      0.96      0.96        27
#    macro avg       0.98      0.83      0.89        27
# weighted avg       0.96      0.96      0.96        27
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/sodre/bin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
