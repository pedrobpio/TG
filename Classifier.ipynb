# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.manifold import TSNE

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# df = pd.read_csv("teste.csv", index_col=0)

# %%
# df[df['ID Aluno']==208149] #id

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.offline as py
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # preparing data

# %%
primeiroCiC = ['116301', '118001', '118010', '113034', '140481', '145971']
segundoCiC = ['116319', '115045', '118028', '118036', '113042']
terceiroCiC = ['118044', '118052', '113956', '113051', '117366']


primeiroLic1 =['116793', '117366', '145971', '147389', '194221']
segundoLic1 = ['113034', '116301', '125156']
terceiroLic1 = ['115045', '116319', '125172']

primeiroLic2 =['113492', '194221', '113450', '113476']
segundoLic2 = ['113034', '116319', '191027', '150649', '194280']
terceiroLic2 = ['115045', '113093', '117366', '117889']

primeiroEngComp =['113034', '113093', '113476', '117528', '118001', '118010']
segundoEngComp = ['118028', '118036', '113042', '115045', '116319']
terceiroEngComp =['113051', '117242', '170054', '201600', '206075']


primeiroMec = ['114626', '114634', '118010', '113476', '113034', '118001', '168891']
segundoMec = ['168891', '113093', '118028', '118036', '115045', '168874']
terceiroMec = ['113051', '118044', '118052', '168769', '116319']

primeiroRedes = ['113034', '113093', '118001', '118010', '167959']
segundoRedes = ['113042', '115045', '118028', '118036', '169676']
terceiroRedes = ['113051', '113301', '167983', '169749']


undropableCol = ["curso","saiu","Cotista","Raça","Sexo","Tipo de Escola"]#, 'Ingresso_unb'

# %%
df0 = pd.read_csv("aluno_quant_Materias_Media_cotistas_0.csv", index_col=0)
df1 = pd.read_csv("aluno_quant_Materias_Media_cotistas_1.csv", index_col=0)
df2 = pd.read_csv("aluno_quant_Materias_Media_cotistas_2.csv", index_col=0)
df3 = pd.read_csv("aluno_quant_Materias_Media_cotistas_3.csv", index_col=0)
df4 = pd.read_csv("aluno_quant_Materias_Media_cotistas_4.csv", index_col=0)
df5 = pd.read_csv("aluno_quant_Materias_Media_cotistas_5.csv", index_col=0)

# %%
dfComp = df0[undropableCol+primeiroLic1+segundoLic1+terceiroLic1].fillna(-1)
dfRedes = df1[undropableCol+primeiroRedes+segundoRedes+terceiroRedes].fillna(-1)
dfCic = df2[undropableCol+primeiroCiC+segundoCiC+terceiroCiC].fillna(-1) 
dfMec = df3[undropableCol+primeiroMec+segundoMec+terceiroMec].fillna(-1) 
dfEng = df4[undropableCol+primeiroEngComp+segundoEngComp+terceiroEngComp].fillna(-1)

# %% [markdown]
# # PCA

# %%
def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)

# %%
def PCA (df, currentLabel = 'saiu'):
    data = (
        df

    )
    
    x = data.iloc[:].values
    y = data[currentLabel].values

    data[currentLabel]
    numColors = len(data[currentLabel].unique())

    sklearn_pca = sklearnPCA(n_components=2)

    Y_sklearn = sklearn_pca.fit_transform(x)

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    with plt.style.context('seaborn-whitegrid'):
        plt.figure(figsize=(15, 10))
        for lab, col in zip(data[currentLabel].unique(),
                            colorList):
            plt.scatter(Y_sklearn[y==lab, 0],
                        Y_sklearn[y==lab, 1],
                        label=lab,
                        c=col)
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend(loc='lower right')
        plt.tight_layout()
        plt.show()

    plt.show()

# %% [markdown]
# # TSNE

# %%
def formatColor(color):
    return 'rgb('+str(int(color[0]*255))+','+str(int(color[1]*255))+','+str(int(color[2]*255))+')'

    
def tsne(df, currentLabel = 'saiu'):
    a = df
    X = a.values
    X_embedded = TSNE(n_components=2).fit_transform(X)
    
    
    data = a
    Y_sklearn = X_embedded
    y = data[currentLabel].values
    numColors = len(data[currentLabel].unique())

    cmap = get_cmap(numColors+1)
    colorList = [cmap(i) for i in range(1, numColors+1)]


    traceArr = []
    for lab, col in zip(data[currentLabel].unique(),
                        colorList):
        
        trace1 = go.Scatter(
            x=Y_sklearn[y==lab, 0],
            y=Y_sklearn[y==lab, 1],
#             z=Y_sklearn[y==lab, 2],
            mode='markers',
            name = str(lab),
            marker=dict(
                size=5,
                color=formatColor(col),
                opacity=0.8
            )
        )
        traceArr.append(trace1)

    data = traceArr
    layout = go.Layout(
        margin=dict(
            l=0,
            r=0,
            b=0,
            t=0
        )
    )
    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, filename='3d-scatter-colorscale')

# %%
# draw2dFrame(a, X_embedded, 'saiu')

# %% [markdown]
# # knn

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# a = a[a["saiu"]!=0]
# y = a["saiu"]
# X = a.drop(["saiu"], axis = 1)

# %%
def knn (df, currentLabel = 'saiu'):
    a = df[df[currentLabel]!=0]
    y = a[currentLabel]
    X = a.drop([currentLabel], axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35)
    scaler = StandardScaler()  
    scaler.fit(X_train)

    X_train = scaler.transform(X_train)  
    X_test = scaler.transform(X_test)  
    
    classifier = KNeighborsClassifier(n_neighbors=2)  
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    
    print(confusion_matrix(y_test, y_pred))  
    print(classification_report(y_test, y_pred))

# %%
# scaler = StandardScaler()  
# scaler.fit(X_train)

# X_train = scaler.transform(X_train)  
# X_test = scaler.transform(X_test)

# %%
# classifier = KNeighborsClassifier(n_neighbors=2)  
# classifier.fit(X_train, y_train)
# y_pred = classifier.predict(X_test)

# %%
 
# print(confusion_matrix(y_test, y_pred))  
# print(classification_report(y_test, y_pred))
# knn(X, y)

# %%
# a

# %% [markdown]
# ## Comp

# %%
PCA(dfComp)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfComp)
# Out:
# <div id="5b4aaa11-cfc6-40bf-b11d-e5dd8862593c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("5b4aaa11-cfc6-40bf-b11d-e5dd8862593c")) {
#     Plotly.newPlot("5b4aaa11-cfc6-40bf-b11d-e5dd8862593c", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [9.743988990783691, 8.676817893981934, -5.771255016326904, -0.7922903299331665, 4.75654411315918, 9.394859313964844, -7.3587541580200195, 9.30494499206543, 9.599241256713867, 4.91525411605835, -6.050328254699707, -5.708635330200195, -0.39957693219184875, -6.154804229736328, 3.836698293685913, 1.4032591581344604, -9.027801513671875, 4.020224571228027, -4.874500274658203, -0.050217628479003906, 6.814826965332031, -8.490946769714355, -3.7736949920654297, -10.500149726867676, 9.331731796264648, 3.9817750453948975, 9.459341049194336, -6.406594753265381, 11.191732406616211, 9.33203411102295, 8.70853328704834, 9.10476303100586, -1.2942394018173218, 10.322171211242676, 9.33203411102295, 5.176140308380127, 3.341143846511841, 2.261563301086426, -0.7869556546211243, 7.1051154136657715, 1.8825618028640747, -4.573697090148926, 4.1440582275390625, 7.3721818923950195, 2.0219640731811523, -0.813068687915802, 9.451946258544922, 7.024660587310791, -0.8349705338478088, -0.611354649066925, 1.405536413192749, -3.3403525352478027, -0.30547234416007996, 0.1634395569562912, 6.883739948272705, -3.5175819396972656, 8.313153266906738, 0.7423104643821716, -1.132942795753479, 0.5701606273651123, -3.373351573944092, -1.7962757349014282, 1.9448856115341187, 1.0261199474334717, 1.1118628978729248, 3.068168878555298, -2.2838804721832275, 0.44086843729019165, 8.809683799743652, 6.597535610198975, 7.472713470458984, 1.7744861841201782, 8.346622467041016, -1.3427199125289917, 8.339139938354492, 1.2025861740112305, 0.5649828910827637, 7.4856157302856445, 0.5320031642913818, 0.8086875677108765, 4.673183441162109, 0.870832622051239, 4.638769626617432, 7.4395294189453125, 10.351223945617676, 1.5446958541870117, 8.859864234924316, 7.119049072265625, 2.8817758560180664, 6.953213214874268, 10.197154998779297, 10.197027206420898, 10.197155952453613, 10.530936241149902, 10.551673889160156], "y": [5.247830390930176, 8.402952194213867, -4.859514236450195, -13.406966209411621, -4.329763412475586, 3.628392457962036, -6.182106971740723, 2.2857651710510254, 2.5258078575134277, -0.5062578916549683, -6.056999683380127, -5.931802272796631, -10.687162399291992, -5.396352767944336, -4.1389665603637695, -7.537320613861084, -7.739720344543457, -7.551217079162598, -6.057252407073975, -6.476912498474121, -0.5766313672065735, -9.564644813537598, -5.51779317855835, -7.797059059143066, 4.272770404815674, -5.932246685028076, 6.958559513092041, -7.392754077911377, 5.88372278213501, 4.273283958435059, 4.993312835693359, 2.8162741661071777, -8.071419715881348, -1.8518176078796387, 4.273283958435059, -4.712435245513916, -2.032813310623169, -1.9719910621643066, -11.837904930114746, 6.130837440490723, -2.4957849979400635, -10.928037643432617, -5.576448917388916, -1.512105107307434, -2.454906702041626, -6.7184906005859375, 5.30733585357666, 3.070462465286255, -6.417816162109375, -6.2839226722717285, -10.004770278930664, -9.218134880065918, -6.116229057312012, -5.986353874206543, -0.3020549416542053, -5.27800178527832, 2.8916401863098145, -2.0814220905303955, -7.6566362380981445, -7.127127647399902, -10.727100372314453, -6.4972991943359375, -6.218925476074219, -6.516144275665283, -6.834564208984375, -6.805936336517334, -8.451508522033691, -5.194400310516357, 3.4124603271484375, 4.365774154663086, -1.5361695289611816, -2.231213092803955, 3.818540573120117, -9.558992385864258, 2.1533761024475098, -9.664445877075195, -5.514672756195068, 5.547490119934082, -7.424970626831055, -5.008371353149414, -4.275312900543213, -7.52705717086792, -4.101616382598877, 5.5949387550354, -1.8752269744873047, -6.593392848968506, 2.629199981689453, 3.5561463832855225, -8.550517082214355, 0.011043114587664604, 3.3269524574279785, 3.3275692462921143, 3.3269526958465576, 3.6772093772888184, 3.6746037006378174], "type": "scatter", "uid": "6c26ce22-b4a0-4187-bdbd-98e ...

# %%
knn(dfComp)
# Out:
# [[13  0]
#  [ 5 26]]
#               precision    recall  f1-score   support
#
#           -1       0.72      1.00      0.84        13
#            1       1.00      0.84      0.91        31
#
#    micro avg       0.89      0.89      0.89        44
#    macro avg       0.86      0.92      0.88        44
# weighted avg       0.92      0.89      0.89        44
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# ## Redes

# %%
PCA(dfRedes)

# %%
tsne(dfRedes)

# %%
knn(dfRedes)

# %% [markdown]
# ## Mec

# %%
PCA(dfMec)

# %%
tsne(dfMec)

# %%
knn(dfMec)

# %% [markdown]
# # CIC

# %%
PCA(dfCic)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfCic)
# Out:
# <div id="2f6d7ae2-c34a-4eb8-9e2b-d85ede36749e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("2f6d7ae2-c34a-4eb8-9e2b-d85ede36749e")) {
#     Plotly.newPlot("2f6d7ae2-c34a-4eb8-9e2b-d85ede36749e", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [-0.8692865371704102, 4.720457553863525, 3.530860424041748, 5.833237171173096, 7.859958171844482, 7.138923645019531, 4.589120388031006, 3.7930355072021484, -8.273109436035156, 3.316775321960449, 5.499674320220947, 10.029047966003418, 7.874539375305176, 4.354251861572266, -3.465963840484619, -7.6044464111328125, -2.7515015602111816, 8.206676483154297, -7.014477729797363, -3.567889451980591, 4.910571098327637, -9.212862968444824, 3.2716283798217773, 0.37050917744636536, 5.609386920928955, -4.827819347381592, 0.5964426398277283, 0.10220136493444443, 0.6152172088623047, 9.209754943847656, -4.905792236328125, -0.3264414966106415, 5.136082649230957, 7.540810585021973, 0.19885946810245514, 2.86049485206604, -3.20784854888916, -1.871932029724121, 2.7931101322174072, 6.176095485687256, 1.3869494199752808, -4.639982223510742, -3.4374778270721436, -0.4815198481082916, 1.5814377069473267, 3.9021599292755127, 2.604037284851074, -2.074185609817505, 3.3619606494903564, 0.7137847542762756, 2.0329089164733887, 0.4653911590576172, -1.9389543533325195, -1.798976182937622, 2.505582332611084, 2.707331895828247, -2.2943081855773926, 4.260298252105713, -0.6698665022850037, -2.7421228885650635, -1.2976057529449463, 0.5730245113372803, 0.17992129921913147, -2.8898839950561523, -3.632371425628662, 0.9507670998573303, -2.8034603595733643, -0.4025571942329407, 2.4930686950683594, -0.324232280254364, 1.912337303161621, -2.2826552391052246, -0.08714938163757324, -3.8826663494110107, 3.513745069503784, 4.488827705383301, -3.326481342315674, 0.9233722686767578, -4.7561163902282715, -3.011963129043579, -6.8975396156311035, -7.6338372230529785, -6.178680419921875, -7.70941686630249, -7.5387725830078125], "y": [-3.455335855484009, 0.8301146030426025, 2.4625513553619385, 11.625907897949219, 12.277324676513672, 12.99329948425293, 9.206062316894531, 8.23462200164795, -10.334962844848633, 7.967517375946045, -0.19985969364643097, 13.104828834533691, 4.370669841766357, 10.117668151855469, -3.4863686561584473, -8.330022811889648, -1.6604722738265991, 12.349824905395508, -11.759244918823242, -0.57472825050354, 13.916918754577637, -7.730166912078857, 0.48683974146842957, 1.4289189577102661, 9.397130966186523, -6.636390686035156, 2.4440395832061768, 2.2331411838531494, 3.3339438438415527, 13.786717414855957, -8.66091537475586, 1.7334169149398804, 4.924729347229004, 13.744314193725586, 2.610548257827759, 2.3214430809020996, -6.7428364753723145, -2.5666754245758057, 3.1509218215942383, 9.48077392578125, 0.8501747846603394, -11.836623191833496, -3.5296318531036377, 0.9381495714187622, 2.450958728790283, 3.333052396774292, 2.302467107772827, -0.9981909394264221, 1.6831433773040771, 1.5648199319839478, 3.110961675643921, 1.0627557039260864, -7.776576519012451, -0.6844103336334229, 0.7264134883880615, -0.3812783658504486, -4.843221187591553, 2.047524929046631, 0.8684055805206299, -3.9273464679718018, -3.4753224849700928, 0.812803328037262, 0.8903807997703552, -7.184768199920654, -4.960849285125732, 3.170264482498169, -4.03071928024292, 3.4712889194488525, 0.5541627407073975, 2.1447060108184814, 1.8286354541778564, -1.5512393712997437, 1.5975379943847656, -5.067845344543457, 2.677795648574829, 10.123701095581055, -4.596624851226807, 1.6811325550079346, -4.99601936340332, -8.429996490478516, -8.399982452392578, -6.487947463989258, -5.556285858154297, -7.4285054206848145, -5.7163214683532715], "type": "scatter", "uid": "5c5df2a0-8694-4b34-96bf-b7fab8e3f350"}, {"marker": {"color": "rgb(0,15,255)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "-1", "x": [-9.954960823059082, 5.676797389984131, 9.434447288513184, 9.56756591796875, 9.244799613952637, 8.777276039123535, 9.025391578674316, 9.911553382873535, 8.602409362792969, 10.169609069824219, 9.190876960754395, 9.392708778381348, 8.500988006591797, 9.1084728240966 ...

# %%
knn(dfCic)
# Out:
# [[ 6  1]
#  [ 4 29]]
#               precision    recall  f1-score   support
#
#           -1       0.60      0.86      0.71         7
#            1       0.97      0.88      0.92        33
#
#    micro avg       0.88      0.88      0.88        40
#    macro avg       0.78      0.87      0.81        40
# weighted avg       0.90      0.88      0.88        40
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %% [markdown]
# # Eng

# %%
PCA(dfEng)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
tsne(dfEng)
# Out:
# <div id="f7bce8af-1483-43a3-81bb-19ef61536a63" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f7bce8af-1483-43a3-81bb-19ef61536a63")) {
#     Plotly.newPlot("f7bce8af-1483-43a3-81bb-19ef61536a63", [{"marker": {"color": "rgb(7,255,0)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "1", "x": [5.875856399536133, -7.605771064758301, 0.4042927920818329, -12.626280784606934, -12.142902374267578, -1.6092865467071533, -8.268610954284668, -10.202609062194824, -12.695093154907227, 6.934748649597168, 5.555897235870361, 1.3828113079071045, -10.823469161987305, 3.899876117706299, 2.3041775226593018, 4.231445789337158, 2.779247760772705, -8.525679588317871, -7.911547660827637, -8.839250564575195, -10.33230209350586, 3.380786180496216, -9.089877128601074, -8.958558082580566, 1.4604278802871704, 1.1160378456115723, 2.0219027996063232, 1.3719934225082397, 5.368521690368652, 2.7643508911132812, -8.066485404968262, 2.58365797996521, -8.921335220336914, 5.063587188720703, 2.5261342525482178, 1.2791601419448853, 4.402374267578125, 1.6770600080490112, 6.097438812255859, 3.4071567058563232, 2.439302921295166, 4.925961971282959, 6.73677396774292, 2.779763698577881, -10.060169219970703, -8.689045906066895, -3.3137781620025635, 4.747176647186279, -7.5966105461120605, -2.7756030559539795, -6.811865329742432, 4.302839279174805, 4.885427951812744, 5.218639850616455, -1.9946907758712769, -6.409250736236572, -4.107021331787109, 1.2818166017532349, -4.53286075592041, -3.027747631072998, 0.5183264017105103, 6.156773090362549, 0.945882260799408, 4.05115270614624, 8.268726348876953, -5.303102493286133, 5.70969295501709, 0.5076150298118591, 6.097561359405518, -0.7995980978012085], "y": [-1.7238585948944092, 6.94364070892334, -0.31048905849456787, 6.947849273681641, 9.163039207458496, -6.504449367523193, 3.319209575653076, 5.537542819976807, 6.805308818817139, -4.97951602935791, -3.509275197982788, -2.37703275680542, 7.259179592132568, 0.4628656804561615, -0.9926536679267883, -8.714876174926758, -3.294477701187134, 2.6429121494293213, -3.8716447353363037, 0.844606339931488, 5.931293487548828, -1.2006144523620605, 1.9945789575576782, 0.6351673007011414, 1.2163574695587158, 0.8397001624107361, 0.8321988582611084, 1.3764086961746216, -4.530084609985352, -3.395481824874878, -3.1313631534576416, -2.6067144870758057, -0.05774431303143501, -5.706240653991699, -2.3898277282714844, -0.2225031554698944, -0.2858690619468689, -0.1782550811767578, -5.335734844207764, -3.7854814529418945, -1.5806035995483398, -4.216513156890869, -4.78748083114624, -0.3716999292373657, 5.256338119506836, 1.111820101737976, 2.9800543785095215, -3.364252805709839, -1.3841999769210815, 2.242579936981201, -3.3146004676818848, -5.8691205978393555, -4.548789024353027, -5.170120716094971, 0.5240657925605774, -3.357276201248169, -0.7749161124229431, -0.25571995973587036, 0.30595332384109497, -1.429456353187561, -3.9598195552825928, -4.728647708892822, -5.2443928718566895, -2.2392423152923584, -5.648183822631836, 5.8892436027526855, -5.06099796295166, -1.643904685974121, -5.335656642913818, -1.3932194709777832], "type": "scatter", "uid": "8ab7648c-9a2b-403f-817b-f43159b31514"}, {"marker": {"color": "rgb(0,15,255)", "opacity": 0.8, "size": 5}, "mode": "markers", "name": "0", "x": [-10.002443313598633, -10.528618812561035, -12.32602596282959, -9.60837173461914, -11.908685684204102, -10.439550399780273, -11.676356315612793, -10.505202293395996, 6.67600154876709, -12.136724472045898, 7.241145610809326, -9.960021018981934, -7.7655839920043945, -13.452685356140137, -6.50092887878418, -13.085004806518555, -8.359012603759766, -12.015149116516113, -11.153922080993652, -7.8802809715271, -11.654675483703613, -4.273228168487549, -5.953151226043701, -12.237648963928223, -7.540610313415527, -7.727025032043457, -6.82979154586792, -12.36376667022705, -8.198760032653809, -6.965893745422363, -5.800027370452881, -5.966527938842773, -4.840436935424805, -6.972917556762695, 0.5135664939880371, -7.371079444885254, -5.021294116973877, -6.7663445472717285, 0.6764062643051147, -2.7589781284332275, -5.4066853523254395, -6.86829137802124, -1.920859217643737 ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("f7bce8af-1483-43a3-81bb-19ef61536a63")) {window._Plotly.Plots.resize(document.getElementById("f7bce8af-1483-43a3-81bb-19ef61536a63"));};})</script>

# %%
knn(dfEng)
# Out:
# [[ 2  0]
#  [ 1 24]]
#               precision    recall  f1-score   support
#
#           -1       0.67      1.00      0.80         2
#            1       1.00      0.96      0.98        25
#
#    micro avg       0.96      0.96      0.96        27
#    macro avg       0.83      0.98      0.89        27
# weighted avg       0.98      0.96      0.97        27
# /home/pedro/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#
# /home/pedro/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
