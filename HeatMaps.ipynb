# %%
# importa, seta configuracao, le arquivo e tira colunas 'unnamed'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
from pandas.plotting import parallel_coordinates

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
df = pd.read_csv('dados_filtrados_v4_cotistas.csv')

# %%
df
# Out:
#        ID Aluno  Sexo Data de Nascimento  Cotista  Tipo de Escola  Raça  Curso  Período de Ingresso na Unb  Período de saída da opção  Ano e Semestre  Média do período  Créditos cursados no total  Créditos cursados no semestre(com aprovação)  Código da disciplina  Créditos disciplina Menção na disciplina  semestre  idade  saiu
# 0        104476     1        1973-09-26         1               0     0      0                       20041                      20042           20041               0.0                           0                                             0                113034                    6                   SR       0.0     30     1
# 1        104476     1        1973-09-26         1               0     0      0                       20041                      20042           20041               0.0                           0                                             0                116301                    6                   SR       0.0     30     1
# ...

# %%
f = (
    df.loc[:, ['Sexo', 'Tipo de Escola', 'Raça', 'Curso', 'Créditos cursados no total', 'Créditos cursados no semestre(com aprovação)',
              'Média do período', 'Menção na disciplina', 'Código da disciplina','semestre', 'idade', 'saiu']]
        .dropna()
).corr()
plt.figure(figsize=(16, 6))
sns.heatmap(f, annot=True)

# %%
def drawHeatMap(df, title):
    f = (
    df.loc[:, ['Sexo', 'Tipo de Escola', 'Raça', 'Créditos cursados no total', 'Créditos cursados no semestre(com aprovação)',
              'Média do período', 'Menção na disciplina', 'Código da disciplina','semestre', 'idade', 'saiu']]
        .dropna()
    ).corr()
    plt.figure(figsize=(16, 6))
    ax = plt.axes()
    sns.heatmap(f, annot=True, ax = ax)
    ax.set_title(title)

def drawHeatMapCov(df):
    f = (
    df.loc[:, ['Sexo', 'Tipo de Escola', 'Raça', 'Créditos cursados no total', 'Créditos cursados no semestre(com aprovação)',
              'Média do período', 'Menção na disciplina', 'Código da disciplina','semestre', 'idade', 'saiu']]
        .dropna()
    ).cov()
    plt.figure(figsize=(16, 6))
    ax = plt.axes()
    sns.heatmap(f, annot=True, ax = ax)
    ax.set_title(df['Curso'].values[0])

# %%
df0 = pd.read_csv('dados_filtrados_v4_cotistas_0.csv')
df1 = pd.read_csv('dados_filtrados_v4_cotistas_1.csv')
df2 = pd.read_csv('dados_filtrados_v4_cotistas_2.csv')
df3 = pd.read_csv('dados_filtrados_v4_cotistas_3.csv')
df4 = pd.read_csv('dados_filtrados_v4_cotistas_4.csv')
df5 = pd.read_csv('dados_filtrados_v4_cotistas_5.csv')

# %%
def drawParallelGraph(df, labelColumn='Raça'):
    plt.figure(figsize=(30, 10))
    f = (
    df.loc[:, ['Sexo', 'Tipo de Escola', 'Raça', 'Créditos cursados no semestre(com aprovação)',
              'Média do período', 'Menção na disciplina','semestre', 'idade', 'saiu']]
        .dropna()
    )
    f[labelColumn] = df[labelColumn]
#     f = f.sample(300)
    parallel_coordinates(f, labelColumn)

# %%
dfQuant = pd.read_csv('aluno_quant_Materias.csv')

# %%
total_sum = dfQuant.sum().sort_values(ascending=False)
total_sum[total_sum > 1000].size

# Relacao entre desempenho nas diciplina x e desepenho no curso
# verificar cargalos das diciplinas ex: OAC, AUTOMATOS
# Out:
# 72

# %%
drawHeatMap(df0, 'heatmap curso computação')

# %%
drawHeatMap(df1, 'heatmap curso Redes')

# %%
drawHeatMap(df2, 'heatmap curso ciencia da computação')

# %%
drawHeatMap(df3, 'heatmap curso Mecatronica')

# %%
drawHeatMap(df4, 'heatmap curso engenharia da computação')

# %%
drawHeatMap(df5, 'heatmap curso engenharia de software')
